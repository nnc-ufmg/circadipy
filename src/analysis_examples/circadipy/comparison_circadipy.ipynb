# %%
## IMPORT LIBRARIES ----------------------------------------------------------------------------------------------------

# %matplotlib qt

# %reload_ext autoreload
# %autoreload 3

import sys                                                                                                              # Import sys to add paths to libraries
import re                                                                                                               # Import re to work with regular expressions
import glob                                                                                                             # Import glob to read files
import matplotlib.pyplot as plt                                                                                         # Import matplotlib.pyplot to plot figures
import tkinter as tk                                                                                                    # Import TK to open folder dialogs to select folders
from tkinter import filedialog                                                                                          # Import filedialog to open folder dialogs to select folders
import numpy                                                                                                            # Import numpy to work with arrays and make calculations
from shutil import rmtree
import random                                                                                                           # Import random to make random choices
from datetime import datetime, timedelta                                                                                # Import time to measure time 
import time                                                                                                             # Import time to measure time
import os                                                                                                               # Import path to work with paths
import pandas                                                                                                           # Import pandas to work with dataframes
import warnings                                                                                                         # Import warnings to ignore warnings
warnings.filterwarnings('ignore')                                                                                       # Ignore warnings

## IMPORT CIRCADIPY ----------------------------------------------------------------------------------------------------

parent_path = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(parent_path)
import chrono_reader as chr                                                                                             # Import chrono_reader to read data
import chrono_plotter as chp                                                                                            # Import chrono_plotter to plot data
import chrono_rhythm as chrt                                                                                             # Import chrono_rithm to make calculations
import chrono_simulation as chs                                                                                         # Import chrono_simulation to simulate data

# %% [markdown]
# ### SELECT THE FILE TO SAVE THE SIMULATIONS

# %%
root = tk.Tk()                                                                                                          # Create the root window
root.attributes('-topmost',True)                                                                                        # Keep the window on top of others
root.iconify()                                                                                                          # Hide the root window

main_save_folder = filedialog.askdirectory(title="Select the folder to save the simulated data", parent=root)           # Ask for the folder to save the simulated data
root.destroy()                                                                                                          # Destroy the root window

print(main_save_folder)                                                                                                 # Print the folder to save the simulated data
# Out:
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy

# %%
def reset_folder(folder):                                                                                               # Function to reset the folder
    for root, dirs, files in os.walk(folder):                                                                           # For each file in the folder
        for f in files:                                                                                                 # For each file
            os.unlink(os.path.join(root, f))                                                                            # Remove the file
        for d in dirs:                                                                                                  # For each folder
            rmtree(os.path.join(root, d))                                                                               # Remove the folder

# %% [markdown]
# ### RUN AND SAVE THE SIMULATIONS
#
# Each simulation has X cycles (num_cycles), each cycle can be configured with a single activity period. Example: for simulations with a light cycle of 12 hours light and 12 hours dark for 5 days, you have 5 days of this cycle (cycle_days) with a period (activity_period) of 24 hours.

# %%
## CREATE THE FOLDERS --------------------------------------------------------------------------------------------------

remove_file = False                                                                                                     # If the file should be removed

save_folder = main_save_folder + '/data_circadipy/'                                                                     # Define the folder to save the data
result_folder = main_save_folder + '/results_circadipy/'                                                                # Define the folder to save the results

if not os.path.exists(save_folder):
    os.makedirs(save_folder)
else:
    if remove_file:                                                                                                     # If the file should be removed
        reset_folder(save_folder)                                                                                       # Reset the folder
        print("Data folder reseted")                                                                                    # Print that the folder was reseted
    else:                                                                                                               # If the file shouldn't be removed
        print("Data folder already exists")                                                                             # Print that the folder already exists

if not os.path.exists(result_folder):
    os.makedirs(result_folder)
else:
    if remove_file:                                                                                                     # If the file should be removed
        reset_folder(result_folder)                                                                                     # Reset the folder
        print("Result folder reseted")                                                                                  # Print that the folder was reseted
    else:                                                                                                               # If the file shouldn't be removed
        print("Result folder already exists")                                                                           # Print that the folder already exists

## SETTING UP THE SIMULATIONS ------------------------------------------------------------------------------------------

num_cycles = 2                                                                                                          # Number of cycles in each simulation
simulations_num = 10                                                                                                    # Number of simulations to run
sampling_frequency = '30T'                                                                                              # Sampling frequency of the simulated data (30T = 30 minutes)
# Set seed
random.seed(42)

types = ['sine', 'square', 'sawtooth']                                                                                  # Types of simulated data
noise_levels = [0.1, 0.5, 1, 5, 10]

simulations = {}                                                                                                        # Dictionary to store the simulations data
for t in types:    
    simulations[t] = {}                                                                                                 # Create a dictionary to store the type data                                                                                       # Create a dictionary to store the noise level data
    for s in range(simulations_num):                                                                                    # For each simulation
        s = str(s)
        simulations[t][s] = {}                                                                                          # Create a dictionary to store the simulation data
        simulations[t][s]['cycles_days'] = [random.randint(3, 10) for _ in range(num_cycles)]                           # Randomly generate the number of days in each cycle (5 cycles)
        simulations[t][s]['activity_period'] = [random.randint(2200, 2600)/100 for _ in range(num_cycles)]              # Randomly generate the activity period in each cycle (5 cycles)
# Out:
# Data folder already exists
# Result folder already exists

# %%
for t in types:    
    for s in simulations[t]:                                                                                            # For each simulation
        file_name = 'simulated_data_' + s + '_' + t                                                                     # Create the file name for the simulated data without noise
        cycle_days = simulations[t][s]['cycles_days']                                                                   # Get the number of days in each cycle
        activity_period = simulations[t][s]['activity_period']                                                          # Get the activity period in each cycle

        data_raw_without_noise = chs.simulate_protocol(file_name, save_folder, sampling_frequency, 
                                                       cycle_days, activity_period, signal_type = t, 
                                                       noise = False, snr_db = 20, only_positive = True, 
                                                       remove_file = True)                                              # Simulate the data with noise (chrono_simulation.py)
        simulations[t][s][file_name] = data_raw_without_noise                                                           # Store the data with noise in the simulations dictionary
        
        for n in noise_levels:       
            if len(str(n)) == 1:
                str_n = '0' + str(n) 
            else:
                str_n = str(n)
            file_name_noise = 'simulated_data_' + s + '_' + t + '_' + str_n                                             # Create the file name for the simulated data with noise
            data_raw_with_noise = chs.simulate_protocol(file_name_noise, save_folder, sampling_frequency, 
                                                        cycle_days, activity_period, signal_type = t, 
                                                        noise = True, snr_db = n, only_positive = True, 
                                                        remove_file = True)                                             # Simulate the data with noise (chrono_simulation.py)

        
            simulations[t][s][file_name_noise] = data_raw_with_noise                                                    # Store the data without noise in the simulations dictionary

        simulation_file = open(save_folder + '/simulation_' + s + '_' + t + '_description.txt', 'w')                    # Create a file to store the simulation description to be used later
        simulation_file.write('Simulation number: ' + s + '\n')                                                         # Write the simulation number
        simulation_file.write('Cycles days: ' + str(simulations[t][s]['cycles_days']) + '\n')                              # Write the cycles days
        simulation_file.write('Activity period: ' + str(simulations[t][s]['activity_period']) + '\n')                      # Write the activity period
        simulation_file.close()                                                                                         # Close the file

        print('Simulation ' + s + ' done!')                                                                             # Print a message to indicate that the simulation is done
# Out:
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_10.asc
# Simulation 0 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_10.asc
# Simulation 1 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_10.asc
# Simulation 2 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_10.asc
# Simulation 3 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_10.asc
# Simulation 4 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_10.asc
# Simulation 5 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_10.asc
# Simulation 6 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_10.asc
# Simulation 7 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_10.asc
# Simulation 8 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_10.asc
# Simulation 9 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_10.asc
# Simulation 0 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_10.asc
# Simulation 1 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_10.asc
# Simulation 2 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_10.asc
# Simulation 3 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_10.asc
# Simulation 4 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_10.asc
# Simulation 5 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_10.asc
# Simulation 6 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_10.asc
# Simulation 7 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_10.asc
# Simulation 8 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_10.asc
# Simulation 9 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_10.asc
# Simulation 0 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_10.asc
# Simulation 1 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_10.asc
# Simulation 2 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_10.asc
# Simulation 3 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_10.asc
# Simulation 4 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_10.asc
# Simulation 5 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_10.asc
# Simulation 6 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_10.asc
# Simulation 7 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_10.asc
# Simulation 8 done!
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_0.1.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_0.5.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_01.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_05.asc
# Saved successfully in C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_10.asc
# Simulation 9 done!

# %%
fig = plt.figure(figsize = (12, 5))                                                                                     # Create a figure
ax = fig.add_subplot(111)                                                                                               # Add a subplot
ax.plot(data_raw_with_noise, color = 'maroon', linewidth = 2)                                                           # Plot the data with noise
ax.plot(data_raw_without_noise, color = 'dimgray', linewidth = 2)                                                       # Plot the data without noise
ax.set_xlabel('Time (Hours)')                                                                                           # Set the x label
ax.set_ylabel('Activity')                                                                                               # Set the y label
ax.legend(['With noise', 'Without noise'])                                                                              # Set the legend
plt.show()                                                                                                              # Show the plot

# %% [markdown]
# ### IMPORT THE SIMULATIONS AND BUILD THE PROTOCOLS TO BE STUDIED

# %%
individual_files = glob.glob(save_folder + "\\*.asc")                                                                   # Get the files for each simulation (with and without noise)

# %%
zt_0_time = 0                                                                                                           # Set the time for the first ZT (0)

simulations = {}                                                                                                        # Create a dictionary to store the simulations data
for file in individual_files:                                                                                           # For each file (each simulation)
    expression = r"\\simulated_data_(.*?)\_(.*?)\.asc"                                                                  # Create a regular expression to get the simulation number and if the data has noise or not
    name_file = re.search(expression, file)                                                                             # Search for the regular expression in the file name
    number = name_file.group(1)                                                                                         # Get the simulation number
    sig_noise = name_file.group(2)                                                                                      # Get if the data has noise or not
    
    if '_' in sig_noise:                                                                                                # If the data has noise
        sig = sig_noise.split('_')[0]                                                                                   # Get only the noise value
        noise = sig_noise.split('_')[1]                                                                                 # Get only the noise value
    else:                                                                                                               # If the data does not have noise
        sig = sig_noise                                                                                                 # Get the value
        noise = '0'                                                                                                     # Set the noise value to 0

    name = number + '_' + sig + '_' + noise                                                                             # Create the name of the simulation
    print(name)

    if sig not in simulations:                                                                                          # If the noise value is not in the dictionary
        simulations[sig] = {}
        simulations[sig][noise] = {}
    else:
        if noise not in simulations[sig]:
            simulations[sig][noise] = {}
    
    simulations[sig][noise][name] = {}                                                                                  # Create a dictionary to store each simulation data (each simulation)
    simulations[sig][noise][name]['file'] = name_file                                                                   # Store the file name
    simulation_file = save_folder + '/simulation_' + number + '_' + sig + '_description.txt'                            # Store the simulation description file name
    simulations[sig][noise][name]['simulation_file'] =simulation_file                                                   # Store the simulation description file name

    simulation_file = open(simulations[sig][noise][name]['simulation_file'], 'r')                                       # Open the simulation description file
    lines = simulation_file.readlines()                                                                                 # Read the lines
    simulation_file.close()                                                                                             # Close the file

    cycle_experssion = r"Cycles days: \[(.*?)\]"                                                                        # Create a regular expression to get the number of days in each cycle
    activity_expression = r"Activity period: \[(.*?)\]"                                                                 # Create a regular expression to get the activity period in each cycle
    cycle_days = re.search(cycle_experssion, lines[1]).group(1)                                                         # Get the number of days in each cycle
    activity_period = re.search(activity_expression, lines[2]).group(1)                                                 # Get the activity period in each cycle

    simulations[sig][noise][name]['cycle_days'] = [int(x) for x in cycle_days.split(', ')]                              # Store the number of days in each cycle
    simulations[sig][noise][name]['activity_period'] = [float(x) for x in activity_period.split(', ')]                  # Store the activity period in each cycle

    labels_dict = {'cycle_types': ['LL', 'LL'], 
                   'test_labels': ['1','2'], 
                   'cycle_days': simulations[sig][noise][name]['cycle_days']}                                           # Create a dictionary to store to pass as argument to the read_protocol function

    print(file)

    protocol = chr.read_protocol(name, file, zt_0_time = zt_0_time, labels_dict = labels_dict, 
                                 type = 'generic', consider_first_day = True)                                           # Read the protocol (chrono_reader.py)
    # protocol.resample('30T', method = 'sum')                                                                          # Resample the data (chrono_reader.py)
    # protocol.apply_filter(window = 3, type = 'moving_average', order = 2, reverse = False)                            # Apply a filter to the data (chrono_reader.py)
    # protocol.normalize_data(type = 'minmax', per_day = True)                                                          # Normalize the data (chrono_reader.py)

    simulations[sig][noise][name]['protocol'] = protocol                                                                # Store the protocol in the simulations dictionary

print(simulations)
# Out:
# 0_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth.asc
# 0_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_0.1.asc
# 0_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_0.5.asc
# 0_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_01.asc
# 0_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_05.asc
# 0_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_10.asc
# 0_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine.asc
# 0_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_0.1.asc
# 0_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_0.5.asc
# 0_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_01.asc
# 0_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_05.asc
# 0_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_10.asc
# 0_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square.asc
# 0_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_0.1.asc
# 0_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_0.5.asc
# 0_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_01.asc
# 0_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_05.asc
# 0_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_10.asc
# 1_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth.asc
# 1_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_0.1.asc
# 1_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_0.5.asc
# 1_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_01.asc
# 1_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_05.asc
# 1_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_10.asc
# 1_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine.asc
# 1_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_0.1.asc
# 1_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_0.5.asc
# 1_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_01.asc
# 1_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_05.asc
# 1_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_10.asc
# 1_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square.asc
# 1_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_0.1.asc
# 1_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_0.5.asc
# 1_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_01.asc
# 1_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_05.asc
# 1_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_10.asc
# 2_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth.asc
# 2_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_0.1.asc
# 2_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_0.5.asc
# 2_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_01.asc
# 2_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_05.asc
# 2_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_10.asc
# 2_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine.asc
# 2_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_0.1.asc
# 2_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_0.5.asc
# 2_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_01.asc
# 2_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_05.asc
# 2_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_10.asc
# 2_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square.asc
# 2_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_0.1.asc
# 2_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_0.5.asc
# 2_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_01.asc
# 2_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_05.asc
# 2_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_10.asc
# 3_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth.asc
# 3_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_0.1.asc
# 3_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_0.5.asc
# 3_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_01.asc
# 3_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_05.asc
# 3_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_10.asc
# 3_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine.asc
# 3_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_0.1.asc
# 3_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_0.5.asc
# 3_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_01.asc
# 3_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_05.asc
# 3_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_10.asc
# 3_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square.asc
# 3_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_0.1.asc
# 3_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_0.5.asc
# 3_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_01.asc
# 3_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_05.asc
# 3_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_10.asc
# 4_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth.asc
# 4_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_0.1.asc
# 4_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_0.5.asc
# 4_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_01.asc
# 4_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_05.asc
# 4_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_10.asc
# 4_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine.asc
# 4_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_0.1.asc
# 4_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_0.5.asc
# 4_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_01.asc
# 4_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_05.asc
# 4_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_10.asc
# 4_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square.asc
# 4_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_0.1.asc
# 4_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_0.5.asc
# 4_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_01.asc
# 4_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_05.asc
# 4_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_10.asc
# 5_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth.asc
# 5_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_0.1.asc
# 5_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_0.5.asc
# 5_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_01.asc
# 5_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_05.asc
# 5_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_10.asc
# 5_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine.asc
# 5_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_0.1.asc
# 5_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_0.5.asc
# 5_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_01.asc
# 5_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_05.asc
# 5_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_10.asc
# 5_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square.asc
# 5_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_0.1.asc
# 5_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_0.5.asc
# 5_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_01.asc
# 5_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_05.asc
# 5_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_10.asc
# 6_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth.asc
# 6_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_0.1.asc
# 6_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_0.5.asc
# 6_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_01.asc
# 6_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_05.asc
# 6_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_10.asc
# 6_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine.asc
# 6_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_0.1.asc
# 6_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_0.5.asc
# 6_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_01.asc
# 6_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_05.asc
# 6_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_10.asc
# 6_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square.asc
# 6_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_0.1.asc
# 6_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_0.5.asc
# 6_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_01.asc
# 6_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_05.asc
# 6_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_10.asc
# 7_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth.asc
# 7_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_0.1.asc
# 7_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_0.5.asc
# 7_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_01.asc
# 7_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_05.asc
# 7_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_10.asc
# 7_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine.asc
# 7_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_0.1.asc
# 7_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_0.5.asc
# 7_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_01.asc
# 7_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_05.asc
# 7_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_10.asc
# 7_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square.asc
# 7_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_0.1.asc
# 7_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_0.5.asc
# 7_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_01.asc
# 7_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_05.asc
# 7_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_10.asc
# 8_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth.asc
# 8_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_0.1.asc
# 8_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_0.5.asc
# 8_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_01.asc
# 8_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_05.asc
# 8_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_10.asc
# 8_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine.asc
# 8_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_0.1.asc
# 8_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_0.5.asc
# 8_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_01.asc
# 8_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_05.asc
# 8_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_10.asc
# 8_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square.asc
# 8_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_0.1.asc
# 8_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_0.5.asc
# 8_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_01.asc
# 8_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_05.asc
# 8_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_10.asc
# 9_sawtooth_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth.asc
# 9_sawtooth_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_0.1.asc
# 9_sawtooth_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_0.5.asc
# 9_sawtooth_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_01.asc
# 9_sawtooth_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_05.asc
# 9_sawtooth_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_10.asc
# 9_sine_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine.asc
# 9_sine_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_0.1.asc
# 9_sine_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_0.5.asc
# 9_sine_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_01.asc
# 9_sine_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_05.asc
# 9_sine_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_10.asc
# 9_square_0
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square.asc
# 9_square_0.1
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_0.1.asc
# 9_square_0.5
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_0.5.asc
# 9_square_01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_01.asc
# 9_square_05
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_05.asc
# 9_square_10
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_10.asc
# {'sawtooth': {'0': {'0_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_0_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_0_sawtooth_description.txt', 'cycle_days': [7, 6], 'activity_period': [25.5, 23.66], 'protocol': <chrono_reader.read_protocol object at 0x00000225DCC9DFA0>}, '1_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_1_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_1_sawtooth_description.txt', 'cycle_days': [3, 6], 'activity_period': [22.16, 23.61], 'protocol': <chrono_reader.read_protocol object at 0x00000225DCB06F40>}, '2_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_2_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_2_sawtooth_description.txt', 'cycle_days': [9, 7], 'activity_period': [22.33, 23.08], 'protocol': <chrono_reader.read_protocol object at 0x00000225DCC018B0>}, '3_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_3_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_3_sawtooth_description.txt', 'cycle_days': [8, 6], 'activity_period': [25.35, 24.55], 'protocol': <chrono_reader.read_protocol object at 0x00000225DFDEBD30>}, '4_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_4_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_4_sawtooth_description.txt', 'cycle_days': [9, 10], 'activity_period': [22.73, 23.35], 'protocol': <chrono_reader.read_protocol object at 0x00000225E0028F70>}, '5_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_5_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_5_sawtooth_description.txt', 'cycle_days': [5, 6], 'activity_period': [25.81, 24.87], 'protocol': <chrono_reader.read_protocol object at 0x00000225E0202EE0>}, '6_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_6_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_6_sawtooth_description.txt', 'cycle_days': [7, 9], 'activity_period': [24.98, 24.04], 'protocol': <chrono_reader.read_protocol object at 0x00000225E0312F10>}, '7_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_7_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_7_sawtooth_description.txt', 'cycle_days': [8, 6], 'activity_period': [22.7, 24.6], 'protocol': <chrono_reader.read_protocol object at 0x00000225E04FCD90>}, '8_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_8_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_8_sawtooth_description.txt', 'cycle_days': [10, 4], 'activity_period': [25.86, 22.24], 'protocol': <chrono_reader.read_protocol object at 0x00000225E0B8E8E0>}, '9_sawtooth_0': {'file': <re.Match object; span=(88, 118), match='\\simulated_data_9_sawtooth.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_9_sawtooth_description.txt', 'cycle_days': [4, 5], 'activity_period': [25.21, 22.81], 'protocol': <chrono_reader.read_protocol object at 0x00000225E0D7EE50>}}, '0.1': {'0_sawtooth_0.1': {'file': <re.Match object; span=(88, 122), match='\\simulated_data_0_sawtooth_0.1.asc'>, 'simulation_file': 'C:/Users/morei/Documents/GitHub/cir ...

# %% [markdown]
# ### CONFIGURE THE FOLDERS TO RECEIVE THE ANALYSIS RESULTS

# %%
remove_file = False                                                                                                     # Set if the file should be removed or not if it already exists

print(result_folder)                                                                                                    # Print the results folder

def reset_folder(folder):                                                                                               # Function to reset the folder
    for root, dirs, files in os.walk(folder):                                                                           # For each file in the folder
        for f in files:                                                                                                 # For each file
            os.unlink(os.path.join(root, f))                                                                            # Remove the file
        for d in dirs:                                                                                                  # For each folder
            rmtree(os.path.join(root, d))                                                                               # Remove the folder

check_folder = os.path.isdir(result_folder)                                                                             # Check if the folder exists
if not check_folder:                                                                                                    # If the folder doesn't exist
    os.makedirs(result_folder)                                                                                          # Create the folder to save the file
    print("Results folder created")                                                                                     # Print that the folder was created
    for count, key in enumerate(list(simulations.keys())):                                                              # For each simulation
        for key_2 in list(simulations[key].keys()):                                                                     # For each key in the simulation   
            simulations[key][key_2]['save_folder'] = result_folder + '\\' + key + '_' + key_2                           # Set the folder to save the file
            check_simulation_folder = os.path.isdir(simulations[key][key_2]['save_folder'])                             # Check if the file exists in the folder
            if check_simulation_folder:                                                                                 # If the file exists
                if remove_file:                                                                                         # If remove_file is True
                    reset_folder(result_folder + '\\' + key + '_' + key_2)                                              # Reset the folder
                    print("Folder " + key + '_' + key_2 + " cleaned!")                                                  # Print that the folder was cleaned
                else:                                                                                                   # If remove_file is False
                    print("Folder already exists")                                                                      # Raise an error
            else:                                                                                                       # If the file doesn't exist
                os.makedirs(simulations[key][key_2]['save_folder'])                                                     # Create the folder to save the file
                print("Folder " + key + '_' + key_2 + " created!")                                                      # Print that the folder was created
else:                                                                                                                   # If the folder exists
    print("Results folder already exists")                                                                              # Print that the folder already exists
    for count, key in enumerate(list(simulations.keys())):                                                              # For each simulation
        for key_2 in list(simulations[key].keys()):                                                                     # For each key in the simulation    
            simulations[key][key_2]['save_folder'] = result_folder + '\\' + key + '_' + key_2                           # Set the folder to save the file
            check_simulation_folder = os.path.isdir(simulations[key][key_2]['save_folder'])                             # Check if the file exists in the folder
            if check_simulation_folder:                                                                                 # If the file exists
                if remove_file:                                                                                         # If remove_file is True
                    reset_folder(result_folder + '\\' + key + '_' + key_2)                                              # Reset the folder
                    print("Folder " + key + '_' + key_2 + " cleaned!")                                                  # Print that the folder was cleaned
                else:                                                                                                   # If remove_file is False
                    print("Folder already exists")                                                                      # Raise an error
            else:                                                                                                       # If the file doesn't exist
                os.makedirs(simulations[key][key_2]['save_folder'])                                                     # Create the folder to save the file
                print("Folder " + key + '_' + key_2 + " created!")                                                      # Print that the folder was created
# Out:
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/
# Results folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists
# Folder already exists

# %% [markdown]
# ### RUN THE MODELING
#
# - The "time_shape" can be 'continuous', 'meadian' or 'mean'. If it is 'continuous', all samples will be cosider to
# calculate the model. If it is 'median' or 'mean', the samples of activity will be grouped by mean/median along one day.
# - The "step" is the time step to calculate the model (in hours).
# - The "start/end_time" defines the period that the model will try to fit. E.g. if the start time is 24, the end time
# is 26, and the step is 0.5, the model will try to fit the data to a cosine curve with period equal to 24, 24.5, 25,
# 25.5 and 26 hours.
# - The "n_components" is the number of components that the model will try to fit. If it is a list, the model will try to
# fit all the number of components in the list. E.g. if n_components = [1,2,3], the model will try to fit the data with
# 1, 2 and 3 components.

# %%
dict = {'time_shape': 'continuous',                     
        'step': 0.01, 
        'start_time': 22, 
        'end_time': 26, 
        'n_components': [1]}                                                                                                                            # Create a dictionary to pass as argument to the fit_cosinor function

best_models = []                                                                                                                                        # Create an empty list to store the best models

for count, sig in enumerate(simulations):                                                                                                               # For each simulation (simulation)
    for noise in simulations[sig]:                                                                                                                      # For each noise level
        result_folder = simulations[sig][noise]['save_folder']                                                                                          # Get the folder to save the file

        for sim in simulations[sig][noise]:                                                                                                             # For each simulation         
            if sim != 'save_folder':                                                                                          
                init = time.time()                                                                                                                      # Get the initial time

                best_models, _ = chrt.fit_cosinor(simulations[sig][noise][sim]['protocol'], dict = dict, save_folder = result_folder)                   # Fit the cosinor to the data (chrono_rithm.py)
                best_models_fixed, _ = chrt.fit_cosinor_fixed_period(simulations[sig][noise][sim]['protocol'], best_models, save_folder = result_folder)# Fix the best period calculated and fit the cosinor for each day using this period (chrono_rithm.py)
                simulations[sig][noise][sim]['best_models'] = best_models                                                                               # Store the best models in the simulations dictionary
                simulations[sig][noise][sim]['best_models_fixed'] = best_models_fixed                                                                   # Store the best models fixed in the simulations dictionary
                
                end = time.time() - init                                                                                                                # Get the time elapsed

                print("Cosinor fitted to " + sig + ' ' + noise + " and results saved!")                                                                 # Print that the cosinor was fitted and the results saved
                print("Time elapsed: " + "{:.2f}".format(end) + " seconds")                                                                             # Print the time elapsed
# Out:
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 19.37 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 12.73 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 18.48 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 16.78 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 22.74 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 14.50 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 23.20 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 22.22 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 29.30 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 20.67 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 21.96 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 15.82 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 18.66 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 17.53 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 21.27 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 15.65 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 18.93 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 16.59 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 16.88 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 12.97 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 16.30 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 13.00 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 19.02 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 16.91 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 20.59 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 15.12 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 19.54 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 16.72 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 17.23 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 13.13 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 15.70 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 13.52 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 18.76 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 16.99 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 20.87 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 14.71 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 19.11 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 19.39 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 20.33 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 16.23 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 17.36 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 13.05 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 18.43 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 16.91 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 20.84 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 14.77 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 18.51 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 17.07 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 16.59 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 12.31 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 15.51 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 12.74 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 18.07 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 16.59 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 20.24 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 14.62 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 18.02 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 16.64 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 17.33 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 12.66 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 11.26 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 15.11 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 12.00 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 10.59 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 12.46 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 17.21 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 13.94 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 18.73 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 16.55 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 15.74 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 11.33 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 15.92 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 11.94 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 10.28 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 13.08 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 16.96 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 13.40 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 18.83 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 16.76 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 15.78 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 11.29 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 14.97 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 12.16 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 10.80 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 13.04 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 17.29 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 13.81 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 19.03 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 16.59 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 15.78 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 11.41 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 14.93 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 11.98 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 10.47 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 12.46 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 17.15 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 13.65 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 19.30 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 16.50 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 16.15 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 11.27 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 15.02 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 12.01 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 10.40 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 12.78 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 17.42 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 13.54 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 18.97 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 16.13 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 16.29 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 11.27 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 15.06 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 12.10 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 10.53 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 12.72 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 17.19 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 13.82 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 19.27 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 16.65 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 15.86 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 13.77 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 15.79 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 17.96 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 11.29 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 14.45 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 18.20 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 15.92 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 16.30 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 13.08 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 1039.77 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 15.26 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 16.37 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 18.08 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 11.34 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 14.55 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 18.48 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 16.27 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 17.96 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 12.81 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 14.09 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 13.38 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 15.67 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 17.41 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 10.94 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 14.10 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 18.22 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 15.73 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 15.74 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 14.73 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 14.38 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 13.32 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 15.77 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 17.17 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 10.90 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 14.17 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 25.78 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 16.76 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 15.74 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 13.44 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 15.75 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 14.17 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 15.88 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 18.75 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 11.44 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 15.02 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 18.73 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 15.90 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 17.80 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 12.74 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 14.16 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 14.51 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 19.51 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 19.23 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 11.32 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 15.13 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 18.15 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 16.44 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 16.31 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 13.74 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 15.11 seconds

# %% [markdown]
# ### COMPARE THE MODEL RESULTS FOR EACH CYCLE

# %%
read = True                                                                                                                               # If you already ran the analysis, set this to True to read the data instead of running the analysis again
model_error = {}                                                                                                                          # Create an empty list to store the model error
mean_model_error = {}                                                                                                                     # Create an empty list to store the mean model error
std_model_error = {}                                                                                                                      # Create an empty list to store the standard deviation of the model error
num_model_error = {}                                                                                                                      # Create an empty list to store the number of model error

for sig in simulations:
      model_error[sig] = {}                                                                                                               # Create an empty list to store the model error for each type of signal
      mean_model_error[sig] = {}                                                                                                          # Create an empty list to store the mean model error for each type of signal
      std_model_error[sig] = {}                                                                                                           # Create an empty list to store the standard deviation of the model error for each type of signal
      num_model_error[sig] = {}                                                                                                           # Create an empty list to store the number of model error for each type of signal
      for noise in simulations[sig]:
            model_error[sig][noise] = []                                                                                                  # Create an empty list to store the model error for each amplitude of noise            
            result_folder = simulations[sig][noise]['save_folder']                                                                        # Get the folder to save the file
            for sim in simulations[sig][noise]:                                                                                           # For each simulation (simulation)
                  if sim != 'save_folder':  
                        if read == True:
                              type_folder = sim.split('_', 1)[1]                                                                          # Get the type of signal
                              print(result_folder + '/cosinor_' + sim + '_.xlsx')
                              best_models = pandas.read_excel(result_folder + '/cosinor_' + sim + '_.xlsx')                               # Read the data
                              simulations[sig][noise][sim]['best_models'] = best_models                                                    # Store the data in the dictionary
                        
                        simulations[sig][noise][sim]['activity_period_model'] = list(simulations[sig][noise][sim]['best_models']['period']) # Get the activity period calculated by the model
                        
                        for stage in range(len(simulations[sig][noise][sim]['activity_period_model'])):
                              param = simulations[sig][noise][sim]['activity_period_model'][stage]
                              ground_truth = simulations[sig][noise][sim]['activity_period'][stage]
                              print(param, ground_truth)
                              simulation_model_error = param - ground_truth
                                                      
                              model_error[sig][noise].append(simulation_model_error)                                                                # Store the model error in the list

                        mean_model_error[sig][noise] = abs(numpy.mean(model_error[sig][noise]))                         # Calculate the mean model error
                        std_model_error[sig][noise] = numpy.std(model_error[sig][noise])                                # Calculate the standard deviation of the model error
                        num_model_error[sig][noise] = len(model_error[sig][noise])                                      # Calculate the number of model error
# Out:
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_0_sawtooth_0_.xlsx
# 25.66000000000057 25.5
# 23.88000000000029 23.66
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_1_sawtooth_0_.xlsx
# 22.0 22.16
# 23.34000000000021 23.61
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_2_sawtooth_0_.xlsx
# 22.41000000000006 22.33
# 23.18000000000018 23.08
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_3_sawtooth_0_.xlsx
# 25.51000000000055 25.35
# 24.60000000000041 24.55
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_4_sawtooth_0_.xlsx
# 22.89000000000014 22.73
# 23.40000000000022 23.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_5_sawtooth_0_.xlsx
# 25.99000000000062 25.81
# 24.79000000000044 24.87
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_6_sawtooth_0_.xlsx
# 25.2300000000005 24.98
# 23.9200000000003 24.04
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_7_sawtooth_0_.xlsx
# 22.75000000000012 22.7
# 24.28000000000036 24.6
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_8_sawtooth_0_.xlsx
# 25.8700000000006 25.86
# 22.44000000000007 22.24
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_9_sawtooth_0_.xlsx
# 25.8500000000006 25.21
# 22.78000000000012 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_0_sawtooth_0.1_.xlsx
# 25.8600000000006 25.5
# 24.33000000000036 23.66
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_1_sawtooth_0.1_.xlsx
# 22.0 22.16
# 23.34000000000021 23.61
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_2_sawtooth_0.1_.xlsx
# 22.45000000000007 22.33
# 23.3100000000002 23.08
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_3_sawtooth_0.1_.xlsx
# 25.8500000000006 25.35
# 24.02000000000032 24.55
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_4_sawtooth_0.1_.xlsx
# 22.78000000000012 22.73
# 23.08000000000017 23.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_5_sawtooth_0.1_.xlsx
# 24.46000000000038 25.81
# 24.85000000000045 24.87
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_6_sawtooth_0.1_.xlsx
# 25.57000000000056 24.98
# 23.51000000000024 24.04
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_7_sawtooth_0.1_.xlsx
# 22.91000000000014 22.7
# 23.61000000000025 24.6
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_8_sawtooth_0.1_.xlsx
# 25.99000000000062 25.86
# 23.01000000000016 22.24
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_9_sawtooth_0.1_.xlsx
# 25.99000000000062 25.21
# 22.78000000000012 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_0_sawtooth_0.5_.xlsx
# 25.94000000000062 25.5
# 23.87000000000029 23.66
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_1_sawtooth_0.5_.xlsx
# 22.0 22.16
# 23.64000000000026 23.61
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_2_sawtooth_0.5_.xlsx
# 22.50000000000008 22.33
# 23.84000000000029 23.08
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_3_sawtooth_0.5_.xlsx
# 25.75000000000059 25.35
# 24.20000000000034 24.55
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_4_sawtooth_0.5_.xlsx
# 23.24000000000019 22.73
# 23.41000000000022 23.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_5_sawtooth_0.5_.xlsx
# 25.02000000000047 25.81
# 23.83000000000029 24.87
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_6_sawtooth_0.5_.xlsx
# 24.87000000000045 24.98
# 24.45000000000038 24.04
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_7_sawtooth_0.5_.xlsx
# 22.80000000000013 22.7
# 24.81000000000044 24.6
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_8_sawtooth_0.5_.xlsx
# 25.95000000000062 25.86
# 22.49000000000008 22.24
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_9_sawtooth_0.5_.xlsx
# 25.99000000000062 25.21
# 22.37000000000006 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_0_sawtooth_01_.xlsx
# 25.8200000000006 25.5
# 24.16000000000034 23.66
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_1_sawtooth_01_.xlsx
# 22.0 22.16
# 23.59000000000025 23.61
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_2_sawtooth_01_.xlsx
# 22.28000000000004 22.33
# 23.24000000000019 23.08
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_3_sawtooth_01_.xlsx
# 25.99000000000062 25.35
# 24.01000000000031 24.55
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_4_sawtooth_01_.xlsx
# 23.14000000000018 22.73
# 23.2800000000002 23.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_5_sawtooth_01_.xlsx
# 25.8300000000006 25.81
# 25.13000000000049 24.87
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_6_sawtooth_01_.xlsx
# 25.53000000000055 24.98
# 24.27000000000035 24.04
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_7_sawtooth_01_.xlsx
# 22.69000000000011 22.7
# 24.21000000000035 24.6
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_8_sawtooth_01_.xlsx
# 25.62000000000057 25.86
# 22.0 22.24
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_9_sawtooth_01_.xlsx
# 24.85000000000045 25.21
# 23.02000000000016 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_0_sawtooth_05_.xlsx
# 25.92000000000061 25.5
# 23.64000000000026 23.66
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_1_sawtooth_05_.xlsx
# 22.0 22.16
# 23.16000000000018 23.61
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_2_sawtooth_05_.xlsx
# 22.36000000000006 22.33
# 23.23000000000019 23.08
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_3_sawtooth_05_.xlsx
# 25.49000000000055 25.35
# 24.23000000000035 24.55
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_4_sawtooth_05_.xlsx
# 22.85000000000013 22.73
# 23.47000000000023 23.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_5_sawtooth_05_.xlsx
# 25.99000000000062 25.81
# 24.92000000000046 24.87
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_6_sawtooth_05_.xlsx
# 25.40000000000053 24.98
# 24.07000000000032 24.04
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_7_sawtooth_05_.xlsx
# 22.90000000000014 22.7
# 24.19000000000034 24.6
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_8_sawtooth_05_.xlsx
# 25.97000000000062 25.86
# 22.0 22.24
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_9_sawtooth_05_.xlsx
# 25.99000000000062 25.21
# 22.51000000000008 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_0_sawtooth_10_.xlsx
# 25.68000000000058 25.5
# 23.9000000000003 23.66
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_1_sawtooth_10_.xlsx
# 22.0 22.16
# 23.18000000000018 23.61
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_2_sawtooth_10_.xlsx
# 22.39000000000006 22.33
# 23.17000000000018 23.08
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_3_sawtooth_10_.xlsx
# 25.39000000000053 25.35
# 24.48000000000039 24.55
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_4_sawtooth_10_.xlsx
# 22.98000000000015 22.73
# 23.40000000000022 23.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_5_sawtooth_10_.xlsx
# 25.99000000000062 25.81
# 24.5800000000004 24.87
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_6_sawtooth_10_.xlsx
# 25.31000000000052 24.98
# 23.9200000000003 24.04
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_7_sawtooth_10_.xlsx
# 22.76000000000012 22.7
# 24.19000000000034 24.6
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_8_sawtooth_10_.xlsx
# 25.72000000000058 25.86
# 22.70000000000011 22.24
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_9_sawtooth_10_.xlsx
# 25.80000000000059 25.21
# 22.57000000000009 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_0_sine_0_.xlsx
# 25.79000000000059 25.79
# 23.40000000000022 23.4
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_1_sine_0_.xlsx
# 22.71000000000011 22.71
# 25.77000000000059 25.77
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_2_sine_0_.xlsx
# 25.02000000000047 25.02
# 24.16000000000034 24.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_3_sine_0_.xlsx
# 22.47000000000007 22.47
# 23.11000000000017 23.11
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_4_sine_0_.xlsx
# 24.87000000000045 24.87
# 23.01000000000016 23.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_5_sine_0_.xlsx
# 24.29000000000036 24.29
# 25.01000000000047 25.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_6_sine_0_.xlsx
# 25.88000000000061 25.88
# 22.81000000000013 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_7_sine_0_.xlsx
# 23.42000000000022 23.42
# 22.79000000000012 22.79
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_8_sine_0_.xlsx
# 22.52000000000008 22.52
# 22.47000000000007 22.47
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_9_sine_0_.xlsx
# 23.83000000000029 23.83
# 23.76000000000028 23.76
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_0_sine_0.1_.xlsx
# 25.99000000000062 25.79
# 23.47000000000023 23.4
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_1_sine_0.1_.xlsx
# 22.80000000000013 22.71
# 25.99000000000062 25.77
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_2_sine_0.1_.xlsx
# 25.99000000000062 25.02
# 24.01000000000031 24.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_3_sine_0.1_.xlsx
# 22.77000000000012 22.47
# 23.13000000000018 23.11
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_4_sine_0.1_.xlsx
# 24.73000000000043 24.87
# 22.0 23.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_5_sine_0.1_.xlsx
# 24.62000000000041 24.29
# 25.10000000000048 25.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_6_sine_0.1_.xlsx
# 25.93000000000061 25.88
# 23.9300000000003 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_7_sine_0.1_.xlsx
# 23.18000000000018 23.42
# 22.84000000000013 22.79
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_8_sine_0.1_.xlsx
# 22.46000000000007 22.52
# 22.32000000000005 22.47
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_9_sine_0.1_.xlsx
# 23.75000000000027 23.83
# 23.9400000000003 23.76
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_0_sine_0.5_.xlsx
# 25.27000000000051 25.79
# 23.47000000000023 23.4
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_1_sine_0.5_.xlsx
# 22.54000000000008 22.71
# 25.99000000000062 25.77
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_2_sine_0.5_.xlsx
# 24.5700000000004 25.02
# 24.28000000000036 24.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_3_sine_0.5_.xlsx
# 22.28000000000004 22.47
# 22.57000000000009 23.11
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_4_sine_0.5_.xlsx
# 24.75000000000043 24.87
# 23.20000000000019 23.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_5_sine_0.5_.xlsx
# 24.30000000000036 24.29
# 25.1700000000005 25.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_6_sine_0.5_.xlsx
# 25.99000000000062 25.88
# 22.96000000000015 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_7_sine_0.5_.xlsx
# 23.44000000000023 23.42
# 22.91000000000014 22.79
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_8_sine_0.5_.xlsx
# 22.33000000000005 22.52
# 22.40000000000006 22.47
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_9_sine_0.5_.xlsx
# 23.88000000000029 23.83
# 23.81000000000028 23.76
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_0_sine_01_.xlsx
# 25.06000000000048 25.79
# 22.22000000000003 23.4
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_1_sine_01_.xlsx
# 22.45000000000007 22.71
# 25.8300000000006 25.77
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_2_sine_01_.xlsx
# 24.82000000000044 25.02
# 23.82000000000028 24.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_3_sine_01_.xlsx
# 22.78000000000012 22.47
# 23.05000000000016 23.11
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_4_sine_01_.xlsx
# 25.10000000000048 24.87
# 22.76000000000012 23.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_5_sine_01_.xlsx
# 24.03000000000032 24.29
# 24.76000000000043 25.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_6_sine_01_.xlsx
# 25.65000000000057 25.88
# 22.6600000000001 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_7_sine_01_.xlsx
# 23.54000000000024 23.42
# 22.59000000000009 22.79
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_8_sine_01_.xlsx
# 22.41000000000006 22.52
# 22.37000000000006 22.47
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_9_sine_01_.xlsx
# 23.87000000000029 23.83
# 23.66000000000026 23.76
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_0_sine_05_.xlsx
# 25.99000000000062 25.79
# 23.60000000000025 23.4
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_1_sine_05_.xlsx
# 22.74000000000012 22.71
# 25.49000000000055 25.77
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_2_sine_05_.xlsx
# 24.66000000000042 25.02
# 24.12000000000033 24.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_3_sine_05_.xlsx
# 23.07000000000017 22.47
# 23.2900000000002 23.11
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_4_sine_05_.xlsx
# 24.92000000000046 24.87
# 22.68000000000011 23.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_5_sine_05_.xlsx
# 24.34000000000037 24.29
# 25.02000000000047 25.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_6_sine_05_.xlsx
# 25.99000000000062 25.88
# 23.10000000000017 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_7_sine_05_.xlsx
# 23.2500000000002 23.42
# 22.77000000000012 22.79
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_8_sine_05_.xlsx
# 22.60000000000009 22.52
# 22.48000000000008 22.47
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_9_sine_05_.xlsx
# 23.81000000000028 23.83
# 23.9500000000003 23.76
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_0_sine_10_.xlsx
# 25.97000000000062 25.79
# 23.08000000000017 23.4
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_1_sine_10_.xlsx
# 22.77000000000012 22.71
# 25.68000000000058 25.77
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_2_sine_10_.xlsx
# 25.12000000000049 25.02
# 24.24000000000035 24.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_3_sine_10_.xlsx
# 22.73000000000011 22.47
# 23.56000000000024 23.11
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_4_sine_10_.xlsx
# 24.80000000000044 24.87
# 23.3000000000002 23.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_5_sine_10_.xlsx
# 24.31000000000036 24.29
# 24.92000000000046 25.01
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_6_sine_10_.xlsx
# 25.8300000000006 25.88
# 22.6200000000001 22.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_7_sine_10_.xlsx
# 23.43000000000022 23.42
# 22.81000000000013 22.79
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_8_sine_10_.xlsx
# 22.50000000000008 22.52
# 22.48000000000008 22.47
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_9_sine_10_.xlsx
# 23.83000000000029 23.83
# 23.62000000000025 23.76
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_0_square_0_.xlsx
# 25.79000000000059 25.73
# 24.67000000000042 24.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_1_square_0_.xlsx
# 22.44000000000007 22.4
# 24.82000000000044 24.82
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_2_square_0_.xlsx
# 25.00000000000047 24.95
# 22.91000000000014 22.98
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_3_square_0_.xlsx
# 25.39000000000053 25.38
# 23.05000000000016 23.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_4_square_0_.xlsx
# 23.19000000000019 23.19
# 22.6100000000001 22.51
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_5_square_0_.xlsx
# 24.33000000000036 24.32
# 25.28000000000051 25.25
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_6_square_0_.xlsx
# 23.9300000000003 23.89
# 23.88000000000029 23.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_7_square_0_.xlsx
# 25.59000000000056 25.59
# 25.45000000000054 25.49
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_8_square_0_.xlsx
# 24.79000000000044 24.73
# 25.73000000000058 25.73
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_9_square_0_.xlsx
# 24.35000000000037 24.36
# 23.83000000000029 23.94
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_0_square_0.1_.xlsx
# 25.67000000000057 25.73
# 25.95000000000062 24.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_1_square_0.1_.xlsx
# 22.71000000000011 22.4
# 24.78000000000043 24.82
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_2_square_0.1_.xlsx
# 24.89000000000045 24.95
# 22.6200000000001 22.98
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_3_square_0.1_.xlsx
# 25.2000000000005 25.38
# 23.2800000000002 23.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_4_square_0.1_.xlsx
# 23.01000000000016 23.19
# 22.18000000000003 22.51
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_5_square_0.1_.xlsx
# 24.32000000000036 24.32
# 25.47000000000054 25.25
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_6_square_0.1_.xlsx
# 24.09000000000033 23.89
# 24.43000000000038 23.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_7_square_0.1_.xlsx
# 25.75000000000059 25.59
# 25.50000000000055 25.49
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_8_square_0.1_.xlsx
# 24.05000000000032 24.73
# 25.60000000000056 25.73
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_9_square_0.1_.xlsx
# 24.37000000000037 24.36
# 24.17000000000034 23.94
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_0_square_0.5_.xlsx
# 25.60000000000056 25.73
# 25.37000000000053 24.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_1_square_0.5_.xlsx
# 22.28000000000004 22.4
# 24.77000000000043 24.82
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_2_square_0.5_.xlsx
# 25.09000000000048 24.95
# 22.95000000000015 22.98
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_3_square_0.5_.xlsx
# 25.68000000000058 25.38
# 23.69000000000026 23.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_4_square_0.5_.xlsx
# 23.2700000000002 23.19
# 22.10000000000002 22.51
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_5_square_0.5_.xlsx
# 24.35000000000037 24.32
# 25.38000000000053 25.25
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_6_square_0.5_.xlsx
# 23.82000000000028 23.89
# 24.18000000000034 23.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_7_square_0.5_.xlsx
# 25.49000000000055 25.59
# 25.34000000000052 25.49
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_8_square_0.5_.xlsx
# 25.32000000000052 24.73
# 25.54000000000055 25.73
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_9_square_0.5_.xlsx
# 24.37000000000037 24.36
# 24.14000000000033 23.94
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_0_square_01_.xlsx
# 25.66000000000057 25.73
# 25.05000000000048 24.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_1_square_01_.xlsx
# 22.70000000000011 22.4
# 24.71000000000042 24.82
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_2_square_01_.xlsx
# 25.06000000000048 24.95
# 23.05000000000016 22.98
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_3_square_01_.xlsx
# 25.54000000000055 25.38
# 22.52000000000008 23.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_4_square_01_.xlsx
# 23.03000000000016 23.19
# 22.24000000000004 22.51
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_5_square_01_.xlsx
# 24.38000000000037 24.32
# 25.14000000000049 25.25
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_6_square_01_.xlsx
# 23.9500000000003 23.89
# 23.58000000000025 23.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_7_square_01_.xlsx
# 25.53000000000055 25.59
# 25.63000000000057 25.49
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_8_square_01_.xlsx
# 24.49000000000039 24.73
# 25.8300000000006 25.73
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_9_square_01_.xlsx
# 24.33000000000036 24.36
# 23.55000000000024 23.94
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_0_square_05_.xlsx
# 25.92000000000061 25.73
# 25.05000000000048 24.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_1_square_05_.xlsx
# 22.53000000000008 22.4
# 24.91000000000045 24.82
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_2_square_05_.xlsx
# 24.91000000000045 24.95
# 22.87000000000014 22.98
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_3_square_05_.xlsx
# 25.88000000000061 25.38
# 22.6400000000001 23.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_4_square_05_.xlsx
# 23.24000000000019 23.19
# 22.52000000000008 22.51
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_5_square_05_.xlsx
# 24.29000000000036 24.32
# 25.35000000000052 25.25
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_6_square_05_.xlsx
# 23.9000000000003 23.89
# 24.07000000000032 23.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_7_square_05_.xlsx
# 25.65000000000057 25.59
# 25.34000000000052 25.49
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_8_square_05_.xlsx
# 24.47000000000039 24.73
# 25.8300000000006 25.73
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_9_square_05_.xlsx
# 24.40000000000038 24.36
# 24.07000000000032 23.94
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_0_square_10_.xlsx
# 25.77000000000059 25.73
# 24.78000000000043 24.35
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_1_square_10_.xlsx
# 22.46000000000007 22.4
# 24.79000000000044 24.82
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_2_square_10_.xlsx
# 24.93000000000046 24.95
# 22.91000000000014 22.98
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_3_square_10_.xlsx
# 25.46000000000054 25.38
# 23.05000000000016 23.16
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_4_square_10_.xlsx
# 23.23000000000019 23.19
# 22.6100000000001 22.51
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_5_square_10_.xlsx
# 24.28000000000036 24.32
# 25.25000000000051 25.25
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_6_square_10_.xlsx
# 23.97000000000031 23.89
# 23.9000000000003 23.81
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_7_square_10_.xlsx
# 25.69000000000058 25.59
# 25.41000000000053 25.49
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_8_square_10_.xlsx
# 24.73000000000043 24.73
# 25.79000000000059 25.73
# C:/Users/morei/Documents/GitHub/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_9_square_10_.xlsx
# 24.30000000000036 24.36
# 23.75000000000027 23.94

# %%
import pandas

model_error_df = pandas.DataFrame(model_error)
display(model_error_df)

mean_model_error_df = pandas.DataFrame(mean_model_error)
# Pass the first row to the last row
first_row = mean_model_error_df.iloc[0]
mean_model_error = pandas.concat([mean_model_error_df.iloc[1:], first_row.to_frame().T])
mean_model_error_df = mean_model_error_df.add_suffix('_mean')
display(mean_model_error_df)

std_model_error_df = pandas.DataFrame(std_model_error)
# Pass the first row to the last row
first_row = std_model_error_df.iloc[0]
std_model_error_df = pandas.concat([std_model_error_df.iloc[1:], first_row.to_frame().T])
std_model_error_df = std_model_error_df.add_suffix('_std')
display(std_model_error_df)

num_model_error_df = pandas.DataFrame(num_model_error)
# Pass the first row to the last row
first_row = num_model_error_df.iloc[0]
num_model_error_df = pandas.concat([num_model_error_df.iloc[1:], first_row.to_frame().T])
num_model_error_df = num_model_error_df.add_suffix('_num')
display(num_model_error_df)

unique_df = pandas.concat([mean_model_error_df, std_model_error_df, num_model_error_df], axis = 1)
display(unique_df)
# Save excel file
unique_df.to_excel(main_save_folder + '/ground_truth_comparison_results.xlsx')
# Out:
#                                               sawtooth  \
# 0    [0.16000000000056858, 0.22000000000029019, -0....
# 0.1  [0.36000000000059984, 0.6700000000003605, -0.1...
# 0.5  [0.44000000000061945, 0.21000000000028862, -0....
# 01   [0.3200000000006007, 0.5000000000003411, -0.16...
# 05   [0.4200000000006092, -0.019999999999740226, -0...
# 10   [0.1800000000005788, 0.24000000000030042, -0.1...
#
#                                                   sine  \
# 0    [5.897504706808832e-13, 2.2026824808563106e-13...
# 0.1  [0.20000000000062101, 0.07000000000023121, 0.0...
# 0.5  [-0.519999999999488, 0.07000000000023121, -0.1...
# 01   [-0.7299999999995208, -1.1799999999999677, -0....
# 05   [0.20000000000062101, 0.20000000000025153, 0.0...
# 10   [0.18000000000062144, -0.31999999999982975, 0....
#
#                                                 square
# 0    [0.06000000000058847, 0.3200000000004195, 0.04...
# 0.1  [-0.05999999999943029, 1.6000000000006196, 0.3...
# 0.5  [-0.12999999999944123, 1.020000000000529, -0.1...
# 01   [-0.06999999999943185, 0.7000000000004789, 0.3...
# 05   [0.1900000000006088, 0.7000000000004789, 0.130...
# 10   [0.0400000000005889, 0.4300000000004296, 0.060...
#      sawtooth_mean     sine_mean  square_mean
# 0           0.0665  2.900791e-13       0.0225
# 0.1         0.0130  9.300000e-02       0.0730
# 0.5         0.0765  4.900000e-02       0.1075
# 01          0.0610  1.830000e-01       0.0305
# 05          0.0425  3.900000e-02       0.0630
# 10          0.0335  2.550000e-02       0.0240
#      sawtooth_std      sine_std  square_std
# 0.1      0.549655  4.195724e-01    0.441974
# 0.5      0.453456  2.259181e-01    0.318228
# 01       0.321775  3.155170e-01    0.268802
# 05       0.294226  2.162152e-01    0.245888
# 10       0.265486  1.698080e-01    0.120557
# 0        0.203452  1.797943e-13    0.087171
#      sawtooth_num  sine_num  square_num
# 0.1            20        20          20
# 0.5            20        20          20
# 01             20        20          20
# 05             20        20          20
# 10             20        20          20
# 0              20        20          20
#      sawtooth_mean     sine_mean  square_mean  sawtooth_std      sine_std  \
# 0           0.0665  2.900791e-13       0.0225      0.203452  1.797943e-13
# 0.1         0.0130  9.300000e-02       0.0730      0.549655  4.195724e-01
# 0.5         0.0765  4.900000e-02       0.1075      0.453456  2.259181e-01
# 01          0.0610  1.830000e-01       0.0305      0.321775  3.155170e-01
# 05          0.0425  3.900000e-02       0.0630      0.294226  2.162152e-01
# 10          0.0335  2.550000e-02       0.0240      0.265486  1.698080e-01
#
#      square_std  sawtooth_num  sine_num  square_num
# 0      0.087171            20        20          20
# 0.1    0.441974            20        20          20
# 0.5    0.318228            20        20          20
# 01     0.268802            20        20          20
# 05     0.245888            20        20          20
# 10     0.120557            20        20          20

# %%
## PLOT THE RESULTS OF THE COMPARISON ----------------------------------------------------------------------------------

# Plot the mean and std for each signal shape and each noise level
# Set the colors for each row
colors = ['gray', 'darkgray', 'lightsteelblue', 'cornflowerblue', 'royalblue', 'midnightblue']

# Create a figure and axis
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 0.15

# Create a NumPy array with the index values
x = numpy.arange(len(mean_model_error_df.columns))

# Plot each row as a separate bar with a specific color
for i, (index, row) in enumerate(mean_model_error_df.iterrows()):
    if index == '0':
        label_name = 'Without Noise'
    else:
        if index[0] == '0' and index[1] != '.':
            label_name = f'{index[1]}dB'
        else:
            label_name = f'{index}dB'
        
    # bar with error std
    ax.errorbar(x + (i * bar_width), row, yerr=std_model_error_df.loc[index], fmt='none', ecolor='black', capsize=3)
    ax.bar(x + (i * bar_width), row, bar_width, label=label_name, color=colors[i])

# Set the labels and title
ax.set_xticks(x + (2 * bar_width))
ax.set_xticklabels([c.upper().split('_', 1)[0] for c in mean_model_error_df.columns])
# ticks font
ax.tick_params(axis='both', which='major', labelsize=16)

# Set legend to be in row outside the plot
ax.legend(frameon=False, ncol=3, fontsize = 12, bbox_to_anchor=(0.5, 1.2), loc='upper center')
ax.set_xlabel('SIGNAL SHAPE', fontsize = 16)
ax.set_ylabel('ERROR IN HOURS\n(CIRCADIPY - GROUND TRUTH)', fontsize = 16)
ax.set_ylim(-1, 1)

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig('comparison_circadipy.svg')

# %% [markdown]
# ### PLOT THE RESULTS
#
# It may take a while to run

# %%
format = 'svg'

for sig in simulations:
      for noise in simulations[sig]:
            for sim in simulations[sig][noise]:                                                                             # For each simulation (simulation)
                  result_folder = simulations[sig][noise]['save_folder']
                  if sim != 'save_folder': 
                        chp.actogram_bar(simulations[sig][noise][sim]['protocol'], first_hour = 18, save_folder = result_folder, save_suffix = 'bar', adjust_figure = [2, 0.9, 0.80, 0.20, 0.1], format = format, x_label = 'TIME (CT)', ticks_fontsize=[11,11])

                        chp.actogram_colormap(simulations[sig][noise][sim]['protocol'], first_hour = 18, save_folder = result_folder, save_suffix = 'colormap', adjust_figure = [2, 0.9, 0.80, 0.20, 0.1], norm_color = None, format = format, x_label = 'TIME (CT)', ticks_fontsize=[11,11], unit_of_measurement='SIMULATED_AMPLITUDE')
                        chp.data_periodogram(simulations[sig][noise][sim]['protocol'], time_shape = 'continuous', method = 'periodogram', max_period = 48, unit_of_measurement = 'AMPLITUDE_{S}', save_folder = result_folder, save_suffix = 'periodogram', format = format, ticks_fontsize=[14,14], labels_fontsize=[14,16,16])
                        chp.data_periodogram(simulations[sig][noise][sim]['protocol'], time_shape = 'continuous', method = 'welch', max_period = 48, unit_of_measurement = 'AMPLITUDE_{S}', save_folder = result_folder, save_suffix = 'welch', format = format, ticks_fontsize=[14,14], labels_fontsize=[14,16,16])

                        chp.model_overview_detailed(simulations[sig][noise][sim]['protocol'], simulations[sig][noise][sim]['best_models_fixed'], save_folder = result_folder, format = format, ticks_fontsize=[14,14], labels_fontsize=[18,16,16])
                        chp.model_overview(simulations[sig][noise][sim]['protocol'], simulations[sig][noise][sim]['best_models'], save_folder = result_folder, format = format, ticks_fontsize=[14,14], labels_fontsize=[18,16,16])
                        chp.model_over_signal(simulations[sig][noise][sim]['protocol'], simulations[sig][noise][sim]['best_models'], position = 'head', mv_avg_window = 1, save_folder = result_folder, format = format, ticks_fontsize=[12,12])

                        chp.time_serie(simulations[sig][noise][sim]['protocol'], labels= ['TIME SERIES', 'TIME (DAYS)', 'SIMULATED\nAMPLITUDE'], save_folder = result_folder, format = format, ticks_fontsize=[12,12], labels_fontsize=[18,16,16])
                        print(sig, noise, sim)
# Out:
# sawtooth 0 0_sawtooth_0
# sawtooth 0 1_sawtooth_0
# sawtooth 0 2_sawtooth_0
# sawtooth 0 3_sawtooth_0
# sawtooth 0 4_sawtooth_0
# sawtooth 0 5_sawtooth_0
# sawtooth 0 6_sawtooth_0
# sawtooth 0 7_sawtooth_0
# sawtooth 0 8_sawtooth_0
# sawtooth 0 9_sawtooth_0
# sawtooth 0.1 0_sawtooth_0.1
# sawtooth 0.1 1_sawtooth_0.1
# sawtooth 0.1 2_sawtooth_0.1
# sawtooth 0.1 3_sawtooth_0.1
# sawtooth 0.1 4_sawtooth_0.1
# sawtooth 0.1 5_sawtooth_0.1
# sawtooth 0.1 6_sawtooth_0.1
# sawtooth 0.1 7_sawtooth_0.1
# sawtooth 0.1 8_sawtooth_0.1
# sawtooth 0.1 9_sawtooth_0.1
# sawtooth 0.5 0_sawtooth_0.5
# sawtooth 0.5 1_sawtooth_0.5
# sawtooth 0.5 2_sawtooth_0.5
# sawtooth 0.5 3_sawtooth_0.5
# sawtooth 0.5 4_sawtooth_0.5
# sawtooth 0.5 5_sawtooth_0.5
# sawtooth 0.5 6_sawtooth_0.5
# sawtooth 0.5 7_sawtooth_0.5
# sawtooth 0.5 8_sawtooth_0.5
# sawtooth 0.5 9_sawtooth_0.5
# sawtooth 01 0_sawtooth_01
# sawtooth 01 1_sawtooth_01
# sawtooth 01 2_sawtooth_01
# sawtooth 01 3_sawtooth_01
# sawtooth 01 4_sawtooth_01
# sawtooth 01 5_sawtooth_01
# sawtooth 01 6_sawtooth_01
# sawtooth 01 7_sawtooth_01
# sawtooth 01 8_sawtooth_01
# sawtooth 01 9_sawtooth_01
# sawtooth 05 0_sawtooth_05
# sawtooth 05 1_sawtooth_05
# sawtooth 05 2_sawtooth_05
# sawtooth 05 3_sawtooth_05
# sawtooth 05 4_sawtooth_05
# sawtooth 05 5_sawtooth_05
# sawtooth 05 6_sawtooth_05
# sawtooth 05 7_sawtooth_05
# sawtooth 05 8_sawtooth_05
# sawtooth 05 9_sawtooth_05
# sawtooth 10 0_sawtooth_10
# sawtooth 10 1_sawtooth_10
# sawtooth 10 2_sawtooth_10
# sawtooth 10 3_sawtooth_10
# sawtooth 10 4_sawtooth_10
# sawtooth 10 5_sawtooth_10
# sawtooth 10 6_sawtooth_10
# sawtooth 10 7_sawtooth_10
# sawtooth 10 8_sawtooth_10
# sawtooth 10 9_sawtooth_10
# sine 0 0_sine_0
# sine 0 1_sine_0
# sine 0 2_sine_0
# sine 0 3_sine_0
# sine 0 4_sine_0
# sine 0 5_sine_0
# sine 0 6_sine_0
# sine 0 7_sine_0
# sine 0 8_sine_0
# sine 0 9_sine_0
# sine 0.1 0_sine_0.1
# sine 0.1 1_sine_0.1
# sine 0.1 2_sine_0.1
# sine 0.1 3_sine_0.1
# sine 0.1 4_sine_0.1
# sine 0.1 5_sine_0.1
# sine 0.1 6_sine_0.1
# sine 0.1 7_sine_0.1
# sine 0.1 8_sine_0.1
# sine 0.1 9_sine_0.1
# sine 0.5 0_sine_0.5
# sine 0.5 1_sine_0.5
# sine 0.5 2_sine_0.5
# sine 0.5 3_sine_0.5
# sine 0.5 4_sine_0.5
# sine 0.5 5_sine_0.5
# sine 0.5 6_sine_0.5
# sine 0.5 7_sine_0.5
# sine 0.5 8_sine_0.5
# sine 0.5 9_sine_0.5
# sine 01 0_sine_01
# sine 01 1_sine_01
# sine 01 2_sine_01
# sine 01 3_sine_01
# sine 01 4_sine_01
# sine 01 5_sine_01
# sine 01 6_sine_01
# sine 01 7_sine_01
# sine 01 8_sine_01
# sine 01 9_sine_01
# sine 05 0_sine_05
# sine 05 1_sine_05
# sine 05 2_sine_05
# sine 05 3_sine_05
# sine 05 4_sine_05
# sine 05 5_sine_05
# sine 05 6_sine_05
# sine 05 7_sine_05
# sine 05 8_sine_05
# sine 05 9_sine_05
# sine 10 0_sine_10
# sine 10 1_sine_10
# sine 10 2_sine_10
# sine 10 3_sine_10
# sine 10 4_sine_10
# sine 10 5_sine_10
# sine 10 6_sine_10
# sine 10 7_sine_10
# sine 10 8_sine_10
# sine 10 9_sine_10
# square 0 0_square_0
# square 0 1_square_0
# square 0 2_square_0
# square 0 3_square_0
# square 0 4_square_0
# square 0 5_square_0
# square 0 6_square_0
# square 0 7_square_0
# square 0 8_square_0
# square 0 9_square_0
# square 0.1 0_square_0.1
# square 0.1 1_square_0.1
# square 0.1 2_square_0.1
# square 0.1 3_square_0.1
# square 0.1 4_square_0.1
# square 0.1 5_square_0.1
# square 0.1 6_square_0.1
# square 0.1 7_square_0.1
# square 0.1 8_square_0.1
# square 0.1 9_square_0.1
# square 0.5 0_square_0.5
# square 0.5 1_square_0.5
# square 0.5 2_square_0.5
# square 0.5 3_square_0.5
# square 0.5 4_square_0.5
# square 0.5 5_square_0.5
# square 0.5 6_square_0.5
# square 0.5 7_square_0.5
# square 0.5 8_square_0.5
# square 0.5 9_square_0.5
# square 01 0_square_01
# square 01 1_square_01
# square 01 2_square_01
# square 01 3_square_01
# square 01 4_square_01
# square 01 5_square_01
# square 01 6_square_01
# square 01 7_square_01
# square 01 8_square_01
# square 01 9_square_01
# square 05 0_square_05
# square 05 1_square_05
# square 05 2_square_05
# square 05 3_square_05
# square 05 4_square_05
# square 05 5_square_05
# square 05 6_square_05
# square 05 7_square_05
# square 05 8_square_05
# square 05 9_square_05
# square 10 0_square_10
# square 10 1_square_10
# square 10 2_square_10
# square 10 3_square_10
# square 10 4_square_10
# square 10 5_square_10
# square 10 6_square_10
# square 10 7_square_10
# square 10 8_square_10
# square 10 9_square_10

# %% [markdown]
# ### RUN THE MODELING FOR SPECIFIED DAY WINDOWS

# %%
dict = {'day_window': 1, 
        'step': 0.01, 
        'start_time': 22, 
        'end_time': 26, 
        'n_components': [1]}

best_models = []

for sig in simulations:
      for noise in simulations[sig]:
            for sim in simulations[sig][noise]:                                                                             # For each simulation (simulation)
                  result_folder = simulations[sig][noise]['save_folder']
                  if sim != 'save_folder': 
                        init = time.time()

                        best_models_per_day, best_models_per_day_file = chrt.fit_cosinor_per_day(simulations[sig][noise][sim]['protocol'], dict = dict, plot = True, save_folder = result_folder) 
                        chp.model_per_day(simulations[sig][noise][sim]['protocol'], best_models_per_day, dict['day_window'], save_folder = result_folder, save_suffix = '', format = format)   
                        simulations[sig][noise][sim]['best_models_per_day'] = best_models_per_day
                        simulations[sig][noise][sim]['best_models_file_per_day'] = best_models_per_day_file
