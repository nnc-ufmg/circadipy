# %%
## IMPORT LIBRARIES ----------------------------------------------------------------------------------------------------

# %matplotlib qt

# %reload_ext autoreload
# %autoreload 3

import sys                                                                                                              # Import sys to add paths to libraries
import re                                                                                                               # Import re to work with regular expressions
import glob                                                                                                             # Import glob to read files
import matplotlib.pyplot as plt                                                                                         # Import matplotlib.pyplot to plot figures
import tkinter as tk                                                                                                    # Import TK to open folder dialogs to select folders
from tkinter import filedialog                                                                                          # Import filedialog to open folder dialogs to select folders
import numpy                                                                                                            # Import numpy to work with arrays and make calculations
from shutil import rmtree
import random                                                                                                           # Import random to make random choices
from datetime import datetime, timedelta                                                                                # Import time to measure time 
import time                                                                                                             # Import time to measure time
import os                                                                                                               # Import path to work with paths
import pandas                                                                                                           # Import pandas to work with dataframes
import warnings                                                                                                         # Import warnings to ignore warnings
warnings.filterwarnings('ignore')                                                                                       # Ignore warnings

## IMPORT CIRCADIPY ----------------------------------------------------------------------------------------------------

parent_path = os.path.dirname(os.path.dirname(os.getcwd()))
sys.path.append(parent_path)
import chrono_reader as chr                                                                                             # Import chrono_reader to read data
import chrono_plotter as chp                                                                                            # Import chrono_plotter to plot data
import chrono_rhythm as chrt                                                                                             # Import chrono_rithm to make calculations
import chrono_simulation as chs                                                                                         # Import chrono_simulation to simulate data
# Out:
# PyMICE library v. 1.2.1
#
# The library is available under GPL3 license; we ask that reference to our paper
# as well as to the library itself is provided in any published research making
# use of PyMICE. Please run:
#
# >>> print(pm.__REFERENCING__)
#
# for more information (given that the library is imported as `pm`).

# %% [markdown]
# ### SELECT THE FILE TO SAVE THE SIMULATIONS

# %%
root = tk.Tk()                                                                                                          # Create the root window
root.attributes('-topmost',True)                                                                                        # Keep the window on top of others
root.iconify()                                                                                                          # Hide the root window

main_save_folder = filedialog.askdirectory(title="Select the folder to save the simulated data", parent=root)           # Ask for the folder to save the simulated data
root.destroy()                                                                                                          # Destroy the root window

print(main_save_folder)                                                                                                 # Print the folder to save the simulated data
# Out:
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy

# %%
def reset_folder(folder):                                                                                               # Function to reset the folder
    for root, dirs, files in os.walk(folder):                                                                           # For each file in the folder
        for f in files:                                                                                                 # For each file
            os.unlink(os.path.join(root, f))                                                                            # Remove the file
        for d in dirs:                                                                                                  # For each folder
            rmtree(os.path.join(root, d))                                                                               # Remove the folder

# %% [markdown]
# ### RUN AND SAVE THE SIMULATIONS
#
# Each simulation has X cycles (num_cycles), each cycle can be configured with a single activity period. Example: for simulations with a light cycle of 12 hours light and 12 hours dark for 5 days, you have 5 days of this cycle (cycle_days) with a period (activity_period) of 24 hours.

# %%
## CREATE THE FOLDERS --------------------------------------------------------------------------------------------------

remove_file = False                                                                                                     # If the file should be removed

save_folder = main_save_folder + '/data_circadipy/'                                                                     # Define the folder to save the data
result_folder = main_save_folder + '/results_circadipy/'                                                                # Define the folder to save the results

if not os.path.exists(save_folder):
    os.makedirs(save_folder)
else:
    if remove_file:                                                                                                     # If the file should be removed
        reset_folder(save_folder)                                                                                       # Reset the folder
        print("Data folder reseted")                                                                                    # Print that the folder was reseted
    else:                                                                                                               # If the file shouldn't be removed
        print("Data folder already exists")                                                                             # Print that the folder already exists

if not os.path.exists(result_folder):
    os.makedirs(result_folder)
else:
    if remove_file:                                                                                                     # If the file should be removed
        reset_folder(result_folder)                                                                                     # Reset the folder
        print("Result folder reseted")                                                                                  # Print that the folder was reseted
    else:                                                                                                               # If the file shouldn't be removed
        print("Result folder already exists")                                                                           # Print that the folder already exists

## SETTING UP THE SIMULATIONS ------------------------------------------------------------------------------------------

num_cycles = 2                                                                                                          # Number of cycles in each simulation
simulations_num = 10                                                                                                    # Number of simulations to run
sampling_frequency = '30T'                                                                                              # Sampling frequency of the simulated data (30T = 30 minutes)
# Set seed
random.seed(42)

types = ['sine', 'square', 'sawtooth']                                                                                  # Types of simulated data
noise_levels = [0.1, 0.5, 1, 5, 10]

simulations = {}                                                                                                        # Dictionary to store the simulations data
for t in types:    
    simulations[t] = {}                                                                                                 # Create a dictionary to store the type data                                                                                       # Create a dictionary to store the noise level data
    for s in range(simulations_num):                                                                                    # For each simulation
        s = str(s)
        simulations[t][s] = {}                                                                                          # Create a dictionary to store the simulation data
        simulations[t][s]['cycles_days'] = [random.randint(3, 10) for _ in range(num_cycles)]                           # Randomly generate the number of days in each cycle (5 cycles)
        simulations[t][s]['activity_period'] = [random.randint(2200, 2600)/100 for _ in range(num_cycles)]              # Randomly generate the activity period in each cycle (5 cycles)

# %%
simulations
# Out:
# {'sine': {'0': {'cycles_days': [4, 3], 'activity_period': [25.79, 23.4]},
#   '1': {'cycles_days': [6, 6], 'activity_period': [22.71, 25.77]},
#   '2': {'cycles_days': [4, 4], 'activity_period': [25.02, 24.16]},
#   '3': {'cycles_days': [3, 3], 'activity_period': [22.47, 23.11]},
#   '4': {'cycles_days': [6, 3], 'activity_period': [24.87, 23.01]},
#   '5': {'cycles_days': [9, 6], 'activity_period': [24.29, 25.01]},
#   '6': {'cycles_days': [7, 3], 'activity_period': [25.88, 22.81]},
#   '7': {'cycles_days': [9, 8], 'activity_period': [23.42, 22.79]},
#   '8': {'cycles_days': [6, 8], 'activity_period': [22.52, 22.47]},
#   '9': {'cycles_days': [9, 4], 'activity_period': [23.83, 23.76]}},
#  'square': {'0': {'cycles_days': [7, 3], 'activity_period': [25.73, 24.35]},
#   '1': {'cycles_days': [4, 9], 'activity_period': [22.4, 24.82]},
#   '2': {'cycles_days': [7, 8], 'activity_period': [24.95, 22.98]},
#   '3': {'cycles_days': [4, 3], 'activity_period': [25.38, 23.16]},
#   '4': {'cycles_days': [7, 4], 'activity_period': [23.19, 22.51]},
#   '5': {'cycles_days': [9, 7], 'activity_period': [24.32, 25.25]},
#   '6': {'cycles_days': [8, 5], 'activity_period': [23.89, 23.81]},
#   '7': {'cycles_days': [6, 7], 'activity_period': [25.59, 25.49]},
#   '8': {'cycles_days': [4, 5], 'activity_period': [24.73, 25.73]},
#   '9': {'cycles_days': [6, 5], 'activity_period': [24.36, 23.94]}},
#  'sawtooth': {'0': {'cycles_days': [7, 6], 'activity_period': [25.5, 23.66]},
#   '1': {'cycles_days': [3, 6], 'activity_period': [22.16, 23.61]},
#   '2': {'cycles_days': [9, 7], 'activity_period': [22.33, 23.08]},
#   '3': {'cycles_days': [8, 6], 'activity_period': [25.35, 24.55]},
#   '4': {'cycles_days': [9, 10], 'activity_period': [22.73, 23.35]},
#   '5': {'cycles_days': [5, 6], 'activity_period': [25.81, 24.87]},
#   '6': {'cycles_days': [7, 9], 'activity_period': [24.98, 24.04]},
#   '7': {'cycles_days': [8, 6], 'activity_period': [22.7, 24.6]},
#   '8': {'cycles_days': [10, 4], 'activity_period': [25.86, 22.24]},
#   '9': {'cycles_days': [4, 5], 'activity_period': [25.21, 22.81]}}}

# %%
for t in types:    
    for s in simulations[t]:                                                                                            # For each simulation
        file_name = 'simulated_data_' + s + '_' + t                                                                     # Create the file name for the simulated data without noise
        cycle_days = simulations[t][s]['cycles_days']                                                                   # Get the number of days in each cycle
        activity_period = simulations[t][s]['activity_period']                                                          # Get the activity period in each cycle

        data_raw_without_noise = chs.simulate_protocol(file_name, save_folder, sampling_frequency, 
                                                       cycle_days, activity_period, signal_type = t, 
                                                       noise = False, snr_db = 20, only_positive = True, 
                                                       remove_file = True)                                              # Simulate the data with noise (chrono_simulation.py)
        simulations[t][s][file_name] = data_raw_without_noise                                                           # Store the data with noise in the simulations dictionary
        
        for n in noise_levels:       
            if len(str(n)) == 1:
                str_n = '0' + str(n) 
            else:
                str_n = str(n)
            file_name_noise = 'simulated_data_' + s + '_' + t + '_' + str_n                                             # Create the file name for the simulated data with noise
            data_raw_with_noise = chs.simulate_protocol(file_name_noise, save_folder, sampling_frequency, 
                                                        cycle_days, activity_period, signal_type = t, 
                                                        noise = True, snr_db = n, only_positive = True, 
                                                        remove_file = True)                                             # Simulate the data with noise (chrono_simulation.py)

        
            simulations[t][s][file_name_noise] = data_raw_with_noise                                                    # Store the data without noise in the simulations dictionary

        simulation_file = open(save_folder + '/simulation_' + s + '_' + t + '_description.txt', 'w')                    # Create a file to store the simulation description to be used later
        simulation_file.write('Simulation number: ' + s + '\n')                                                         # Write the simulation number
        simulation_file.write('Cycles days: ' + str(simulations[t][s]['cycles_days']) + '\n')                              # Write the cycles days
        simulation_file.write('Activity period: ' + str(simulations[t][s]['activity_period']) + '\n')                      # Write the activity period
        simulation_file.close()                                                                                         # Close the file

        print('Simulation ' + s + ' done!')                                                                             # Print a message to indicate that the simulation is done
# Out:
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sine_10.asc
# Simulation 0 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sine_10.asc
# Simulation 1 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sine_10.asc
# Simulation 2 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sine_10.asc
# Simulation 3 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sine_10.asc
# Simulation 4 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sine_10.asc
# Simulation 5 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sine_10.asc
# Simulation 6 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sine_10.asc
# Simulation 7 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sine_10.asc
# Simulation 8 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sine_10.asc
# Simulation 9 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_square_10.asc
# Simulation 0 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_square_10.asc
# Simulation 1 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_square_10.asc
# Simulation 2 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_square_10.asc
# Simulation 3 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_square_10.asc
# Simulation 4 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_square_10.asc
# Simulation 5 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_square_10.asc
# Simulation 6 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_square_10.asc
# Simulation 7 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_square_10.asc
# Simulation 8 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_square_10.asc
# Simulation 9 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_0_sawtooth_10.asc
# Simulation 0 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_1_sawtooth_10.asc
# Simulation 1 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_2_sawtooth_10.asc
# Simulation 2 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_3_sawtooth_10.asc
# Simulation 3 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_4_sawtooth_10.asc
# Simulation 4 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_5_sawtooth_10.asc
# Simulation 5 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_6_sawtooth_10.asc
# Simulation 6 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_7_sawtooth_10.asc
# Simulation 7 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_8_sawtooth_10.asc
# Simulation 8 done!
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_0.1.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_0.5.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_01.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_05.asc
# Saved successfully in E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulated_data_9_sawtooth_10.asc
# Simulation 9 done!

# %%
fig = plt.figure(figsize = (12, 5))                                                                                     # Create a figure
ax = fig.add_subplot(111)                                                                                               # Add a subplot
ax.plot(data_raw_with_noise, color = 'maroon', linewidth = 2)                                                           # Plot the data with noise
ax.plot(data_raw_without_noise, color = 'dimgray', linewidth = 2)                                                       # Plot the data without noise
ax.set_xlabel('Time (Hours)')                                                                                           # Set the x label
ax.set_ylabel('Activity')                                                                                               # Set the y label
ax.legend(['With noise', 'Without noise'])                                                                              # Set the legend
plt.show()                                                                                                              # Show the plot

# %% [markdown]
# ### IMPORT THE SIMULATIONS AND BUILD THE PROTOCOLS TO BE STUDIED

# %%
individual_files = glob.glob(save_folder + "\\*.asc")                                                                   # Get the files for each simulation (with and without noise)

# %%
zt_0_time = 0                                                                                                           # Set the time for the first ZT (0)

simulations = {}                                                                                                        # Create a dictionary to store the simulations data
for file in individual_files:                                                                                           # For each file (each simulation)
    expression = r"\\simulated_data_(.*?)\_(.*?)\.asc"                                                                  # Create a regular expression to get the simulation number and if the data has noise or not
    name_file = re.search(expression, file)                                                                             # Search for the regular expression in the file name
    number = name_file.group(1)                                                                                         # Get the simulation number
    sig_noise = name_file.group(2)                                                                                      # Get if the data has noise or not
    
    if '_' in sig_noise:                                                                                                # If the data has noise
        sig = sig_noise.split('_')[0]                                                                                   # Get only the noise value
        noise = sig_noise.split('_')[1]                                                                                 # Get only the noise value
    else:                                                                                                               # If the data does not have noise
        sig = sig_noise                                                                                                 # Get the value
        noise = '0'                                                                                                     # Set the noise value to 0

    name = number + '_' + sig + '_' + noise                                                                             # Create the name of the simulation
    print(name)

    if sig not in simulations:                                                                                          # If the noise value is not in the dictionary
        simulations[sig] = {}
        simulations[sig][noise] = {}
    else:
        if noise not in simulations[sig]:
            simulations[sig][noise] = {}
    
    simulations[sig][noise][name] = {}                                                                                  # Create a dictionary to store each simulation data (each simulation)
    simulations[sig][noise][name]['file'] = name_file                                                                   # Store the file name
    simulation_file = save_folder + '/simulation_' + number + '_' + sig + '_description.txt'                            # Store the simulation description file name
    simulations[sig][noise][name]['simulation_file'] =simulation_file                                                   # Store the simulation description file name

    simulation_file = open(simulations[sig][noise][name]['simulation_file'], 'r')                                       # Open the simulation description file
    lines = simulation_file.readlines()                                                                                 # Read the lines
    simulation_file.close()                                                                                             # Close the file

    cycle_experssion = r"Cycles days: \[(.*?)\]"                                                                        # Create a regular expression to get the number of days in each cycle
    activity_expression = r"Activity period: \[(.*?)\]"                                                                 # Create a regular expression to get the activity period in each cycle
    cycle_days = re.search(cycle_experssion, lines[1]).group(1)                                                         # Get the number of days in each cycle
    activity_period = re.search(activity_expression, lines[2]).group(1)                                                 # Get the activity period in each cycle

    simulations[sig][noise][name]['cycle_days'] = [int(x) for x in cycle_days.split(', ')]                              # Store the number of days in each cycle
    simulations[sig][noise][name]['activity_period'] = [float(x) for x in activity_period.split(', ')]                  # Store the activity period in each cycle

    labels_dict = {'cycle_types': ['DD', 'DD'], 
                   'test_labels': ['1','2'], 
                   'cycle_days': simulations[sig][noise][name]['cycle_days']}                                           # Create a dictionary to store to pass as argument to the read_protocol function

    print(file)

    protocol = chr.read_protocol(name, file, zt_0_time = zt_0_time, labels_dict = labels_dict, 
                                 type = 'generic', consider_first_day = True)                                           # Read the protocol (chrono_reader.py)
    # protocol.resample('30T', method = 'sum')                                                                          # Resample the data (chrono_reader.py)
    # protocol.apply_filter(window = 3, type = 'moving_average', order = 2, reverse = False)                            # Apply a filter to the data (chrono_reader.py)
    # protocol.normalize_data(type = 'minmax', per_day = True)                                                          # Normalize the data (chrono_reader.py)

    simulations[sig][noise][name]['protocol'] = protocol                                                                # Store the protocol in the simulations dictionary

print(simulations)
# Out:
# 0_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth.asc
# 0_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_0.1.asc
# 0_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_0.5.asc
# 0_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_01.asc
# 0_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_05.asc
# 0_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sawtooth_10.asc
# 0_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine.asc
# 0_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_0.1.asc
# 0_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_0.5.asc
# 0_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_01.asc
# 0_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_05.asc
# 0_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_sine_10.asc
# 0_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square.asc
# 0_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_0.1.asc
# 0_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_0.5.asc
# 0_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_01.asc
# 0_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_05.asc
# 0_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_0_square_10.asc
# 1_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth.asc
# 1_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_0.1.asc
# 1_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_0.5.asc
# 1_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_01.asc
# 1_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_05.asc
# 1_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sawtooth_10.asc
# 1_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine.asc
# 1_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_0.1.asc
# 1_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_0.5.asc
# 1_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_01.asc
# 1_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_05.asc
# 1_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_sine_10.asc
# 1_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square.asc
# 1_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_0.1.asc
# 1_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_0.5.asc
# 1_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_01.asc
# 1_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_05.asc
# 1_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_1_square_10.asc
# 2_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth.asc
# 2_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_0.1.asc
# 2_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_0.5.asc
# 2_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_01.asc
# 2_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_05.asc
# 2_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sawtooth_10.asc
# 2_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine.asc
# 2_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_0.1.asc
# 2_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_0.5.asc
# 2_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_01.asc
# 2_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_05.asc
# 2_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_sine_10.asc
# 2_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square.asc
# 2_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_0.1.asc
# 2_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_0.5.asc
# 2_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_01.asc
# 2_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_05.asc
# 2_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_2_square_10.asc
# 3_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth.asc
# 3_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_0.1.asc
# 3_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_0.5.asc
# 3_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_01.asc
# 3_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_05.asc
# 3_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sawtooth_10.asc
# 3_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine.asc
# 3_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_0.1.asc
# 3_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_0.5.asc
# 3_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_01.asc
# 3_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_05.asc
# 3_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_sine_10.asc
# 3_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square.asc
# 3_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_0.1.asc
# 3_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_0.5.asc
# 3_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_01.asc
# 3_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_05.asc
# 3_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_3_square_10.asc
# 4_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth.asc
# 4_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_0.1.asc
# 4_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_0.5.asc
# 4_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_01.asc
# 4_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_05.asc
# 4_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sawtooth_10.asc
# 4_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine.asc
# 4_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_0.1.asc
# 4_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_0.5.asc
# 4_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_01.asc
# 4_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_05.asc
# 4_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_sine_10.asc
# 4_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square.asc
# 4_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_0.1.asc
# 4_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_0.5.asc
# 4_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_01.asc
# 4_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_05.asc
# 4_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_4_square_10.asc
# 5_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth.asc
# 5_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_0.1.asc
# 5_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_0.5.asc
# 5_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_01.asc
# 5_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_05.asc
# 5_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sawtooth_10.asc
# 5_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine.asc
# 5_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_0.1.asc
# 5_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_0.5.asc
# 5_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_01.asc
# 5_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_05.asc
# 5_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_sine_10.asc
# 5_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square.asc
# 5_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_0.1.asc
# 5_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_0.5.asc
# 5_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_01.asc
# 5_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_05.asc
# 5_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_5_square_10.asc
# 6_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth.asc
# 6_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_0.1.asc
# 6_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_0.5.asc
# 6_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_01.asc
# 6_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_05.asc
# 6_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sawtooth_10.asc
# 6_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine.asc
# 6_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_0.1.asc
# 6_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_0.5.asc
# 6_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_01.asc
# 6_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_05.asc
# 6_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_sine_10.asc
# 6_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square.asc
# 6_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_0.1.asc
# 6_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_0.5.asc
# 6_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_01.asc
# 6_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_05.asc
# 6_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_6_square_10.asc
# 7_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth.asc
# 7_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_0.1.asc
# 7_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_0.5.asc
# 7_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_01.asc
# 7_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_05.asc
# 7_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sawtooth_10.asc
# 7_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine.asc
# 7_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_0.1.asc
# 7_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_0.5.asc
# 7_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_01.asc
# 7_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_05.asc
# 7_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_sine_10.asc
# 7_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square.asc
# 7_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_0.1.asc
# 7_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_0.5.asc
# 7_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_01.asc
# 7_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_05.asc
# 7_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_7_square_10.asc
# 8_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth.asc
# 8_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_0.1.asc
# 8_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_0.5.asc
# 8_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_01.asc
# 8_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_05.asc
# 8_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sawtooth_10.asc
# 8_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine.asc
# 8_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_0.1.asc
# 8_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_0.5.asc
# 8_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_01.asc
# 8_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_05.asc
# 8_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_sine_10.asc
# 8_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square.asc
# 8_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_0.1.asc
# 8_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_0.5.asc
# 8_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_01.asc
# 8_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_05.asc
# 8_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_8_square_10.asc
# 9_sawtooth_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth.asc
# 9_sawtooth_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_0.1.asc
# 9_sawtooth_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_0.5.asc
# 9_sawtooth_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_01.asc
# 9_sawtooth_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_05.asc
# 9_sawtooth_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sawtooth_10.asc
# 9_sine_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine.asc
# 9_sine_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_0.1.asc
# 9_sine_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_0.5.asc
# 9_sine_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_01.asc
# 9_sine_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_05.asc
# 9_sine_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_sine_10.asc
# 9_square_0
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square.asc
# 9_square_0.1
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_0.1.asc
# 9_square_0.5
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_0.5.asc
# 9_square_01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_01.asc
# 9_square_05
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_05.asc
# 9_square_10
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy\simulated_data_9_square_10.asc
# {'sawtooth': {'0': {'0_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_0_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_0_sawtooth_description.txt', 'cycle_days': [7, 6], 'activity_period': [25.5, 23.66], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA4A68430>}, '1_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_1_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_1_sawtooth_description.txt', 'cycle_days': [3, 6], 'activity_period': [22.16, 23.61], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA4E83BB0>}, '2_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_2_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_2_sawtooth_description.txt', 'cycle_days': [9, 7], 'activity_period': [22.33, 23.08], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA4F70F70>}, '3_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_3_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_3_sawtooth_description.txt', 'cycle_days': [8, 6], 'activity_period': [25.35, 24.55], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA51C5CA0>}, '4_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_4_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_4_sawtooth_description.txt', 'cycle_days': [9, 10], 'activity_period': [22.73, 23.35], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA4F70DF0>}, '5_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_5_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_5_sawtooth_description.txt', 'cycle_days': [5, 6], 'activity_period': [25.81, 24.87], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA0601B80>}, '6_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_6_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_6_sawtooth_description.txt', 'cycle_days': [7, 9], 'activity_period': [24.98, 24.04], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA549DEB0>}, '7_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_7_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_7_sawtooth_description.txt', 'cycle_days': [8, 6], 'activity_period': [22.7, 24.6], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA082EE80>}, '8_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_8_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_8_sawtooth_description.txt', 'cycle_days': [10, 4], 'activity_period': [25.86, 22.24], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA5BC9F10>}, '9_sawtooth_0': {'file': <re.Match object; span=(75, 105), match='\\simulated_data_9_sawtooth.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_9_sawtooth_description.txt', 'cycle_days': [4, 5], 'activity_period': [25.21, 22.81], 'protocol': <chrono_reader.read_protocol object at 0x000001BDA5D4BFA0>}}, '0.1': {'0_sawtooth_0.1': {'file': <re.Match object; span=(75, 109), match='\\simulated_data_0_sawtooth_0.1.asc'>, 'simulation_file': 'E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/data_circadipy//simulation_0_sawtooth_description.txt', 'cycle_days': [7, 6], 'activity_period': [25.5,  ...

# %% [markdown]
# ### CONFIGURE THE FOLDERS TO RECEIVE THE ANALYSIS RESULTS

# %%
remove_file = False                                                                                                     # Set if the file should be removed or not if it already exists

print(result_folder)                                                                                                    # Print the results folder

def reset_folder(folder):                                                                                               # Function to reset the folder
    for root, dirs, files in os.walk(folder):                                                                           # For each file in the folder
        for f in files:                                                                                                 # For each file
            os.unlink(os.path.join(root, f))                                                                            # Remove the file
        for d in dirs:                                                                                                  # For each folder
            rmtree(os.path.join(root, d))                                                                               # Remove the folder

check_folder = os.path.isdir(result_folder)                                                                             # Check if the folder exists
if not check_folder:                                                                                                    # If the folder doesn't exist
    os.makedirs(result_folder)                                                                                          # Create the folder to save the file
    print("Results folder created")                                                                                     # Print that the folder was created
    for count, key in enumerate(list(simulations.keys())):                                                              # For each simulation
        for key_2 in list(simulations[key].keys()):                                                                     # For each key in the simulation   
            simulations[key][key_2]['save_folder'] = result_folder + '\\' + key + '_' + key_2                           # Set the folder to save the file
            check_simulation_folder = os.path.isdir(simulations[key][key_2]['save_folder'])                             # Check if the file exists in the folder
            if check_simulation_folder:                                                                                 # If the file exists
                if remove_file:                                                                                         # If remove_file is True
                    reset_folder(result_folder + '\\' + key + '_' + key_2)                                              # Reset the folder
                    print("Folder " + key + '_' + key_2 + " cleaned!")                                                  # Print that the folder was cleaned
                else:                                                                                                   # If remove_file is False
                    print("Folder already exists")                                                                      # Raise an error
            else:                                                                                                       # If the file doesn't exist
                os.makedirs(simulations[key][key_2]['save_folder'])                                                     # Create the folder to save the file
                print("Folder " + key + '_' + key_2 + " created!")                                                      # Print that the folder was created
else:                                                                                                                   # If the folder exists
    print("Results folder already exists")                                                                              # Print that the folder already exists
    for count, key in enumerate(list(simulations.keys())):                                                              # For each simulation
        for key_2 in list(simulations[key].keys()):                                                                     # For each key in the simulation    
            simulations[key][key_2]['save_folder'] = result_folder + '\\' + key + '_' + key_2                           # Set the folder to save the file
            check_simulation_folder = os.path.isdir(simulations[key][key_2]['save_folder'])                             # Check if the file exists in the folder
            if check_simulation_folder:                                                                                 # If the file exists
                if remove_file:                                                                                         # If remove_file is True
                    reset_folder(result_folder + '\\' + key + '_' + key_2)                                              # Reset the folder
                    print("Folder " + key + '_' + key_2 + " cleaned!")                                                  # Print that the folder was cleaned
                else:                                                                                                   # If remove_file is False
                    print("Folder already exists")                                                                      # Raise an error
            else:                                                                                                       # If the file doesn't exist
                os.makedirs(simulations[key][key_2]['save_folder'])                                                     # Create the folder to save the file
                print("Folder " + key + '_' + key_2 + " created!")                                                      # Print that the folder was created
# Out:
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/
# Results folder already exists
# Folder sawtooth_0 created!
# Folder sawtooth_0.1 created!
# Folder sawtooth_0.5 created!
# Folder sawtooth_01 created!
# Folder sawtooth_05 created!
# Folder sawtooth_10 created!
# Folder sine_0 created!
# Folder sine_0.1 created!
# Folder sine_0.5 created!
# Folder sine_01 created!
# Folder sine_05 created!
# Folder sine_10 created!
# Folder square_0 created!
# Folder square_0.1 created!
# Folder square_0.5 created!
# Folder square_01 created!
# Folder square_05 created!
# Folder square_10 created!

# %% [markdown]
# ### RUN THE MODELING
#
# - The "time_shape" can be 'continuous', 'meadian' or 'mean'. If it is 'continuous', all samples will be cosider to
# calculate the model. If it is 'median' or 'mean', the samples of activity will be grouped by mean/median along one day.
# - The "step" is the time step to calculate the model (in hours).
# - The "start/end_time" defines the period that the model will try to fit. E.g. if the start time is 24, the end time
# is 26, and the step is 0.5, the model will try to fit the data to a cosine curve with period equal to 24, 24.5, 25,
# 25.5 and 26 hours.
# - The "n_components" is the number of components that the model will try to fit. If it is a list, the model will try to
# fit all the number of components in the list. E.g. if n_components = [1,2,3], the model will try to fit the data with
# 1, 2 and 3 components.

# %%
dict = {'time_shape': 'continuous',                     
        'step': 0.01, 
        'start_time': 22, 
        'end_time': 26, 
        'n_components': [1]}                                                                                                                            # Create a dictionary to pass as argument to the fit_cosinor function

best_models = []                                                                                                                                        # Create an empty list to store the best models

for count, sig in enumerate(simulations):                                                                                                               # For each simulation (simulation)
    for noise in simulations[sig]:                                                                                                                      # For each noise level
        result_folder = simulations[sig][noise]['save_folder']                                                                                          # Get the folder to save the file

        for sim in simulations[sig][noise]:                                                                                                             # For each simulation         
            if sim != 'save_folder':                                                                                          
                init = time.time()                                                                                                                      # Get the initial time

                best_models, _ = chrt.fit_cosinor(simulations[sig][noise][sim]['protocol'], dict = dict, save_folder = result_folder)                   # Fit the cosinor to the data (chrono_rithm.py)
                best_models_fixed, _ = chrt.fit_cosinor_fixed_period(simulations[sig][noise][sim]['protocol'], best_models, save_folder = result_folder)# Fix the best period calculated and fit the cosinor for each day using this period (chrono_rithm.py)
                simulations[sig][noise][sim]['best_models'] = best_models                                                                               # Store the best models in the simulations dictionary
                simulations[sig][noise][sim]['best_models_fixed'] = best_models_fixed                                                                   # Store the best models fixed in the simulations dictionary
                
                end = time.time() - init                                                                                                                # Get the time elapsed

                print("Cosinor fitted to " + sig + ' ' + noise + " and results saved!")                                                                 # Print that the cosinor was fitted and the results saved
                print("Time elapsed: " + "{:.2f}".format(end) + " seconds")                                                                             # Print the time elapsed
# Out:
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 15.72 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 10.68 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 17.62 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 16.36 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 16.22 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 10.81 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 13.67 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 12.38 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 12.54 seconds
# Cosinor fitted to sawtooth 0 and results saved!
# Time elapsed: 9.73 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 11.76 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 9.48 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 13.57 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 12.41 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 16.24 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 15.25 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 15.13 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 13.77 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 13.65 seconds
# Cosinor fitted to sawtooth 0.1 and results saved!
# Time elapsed: 10.85 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 13.08 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 10.34 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 15.00 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 17.91 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 20.72 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 11.77 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 15.18 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 15.08 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 14.49 seconds
# Cosinor fitted to sawtooth 0.5 and results saved!
# Time elapsed: 10.79 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 13.03 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 10.89 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 14.82 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 13.72 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 16.67 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 12.00 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 15.74 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 16.83 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 14.15 seconds
# Cosinor fitted to sawtooth 01 and results saved!
# Time elapsed: 10.88 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 13.49 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 10.57 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 14.99 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 13.97 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 17.21 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 11.94 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 15.14 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 13.97 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 13.68 seconds
# Cosinor fitted to sawtooth 05 and results saved!
# Time elapsed: 10.90 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 13.18 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 10.63 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 15.05 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 13.61 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 17.16 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 11.93 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 14.89 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 14.42 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 14.52 seconds
# Cosinor fitted to sawtooth 10 and results saved!
# Time elapsed: 10.63 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 9.80 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 12.85 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 10.01 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 8.70 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 10.72 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 18.51 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 13.10 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 16.24 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 14.23 seconds
# Cosinor fitted to sine 0 and results saved!
# Time elapsed: 13.10 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 9.15 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 11.37 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 9.03 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 7.87 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 10.34 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 18.49 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 11.19 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 15.41 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 14.00 seconds
# Cosinor fitted to sine 0.1 and results saved!
# Time elapsed: 16.33 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 9.79 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 12.84 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 11.06 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 8.86 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 11.18 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 15.19 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 11.89 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 19.62 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 14.09 seconds
# Cosinor fitted to sine 0.5 and results saved!
# Time elapsed: 13.15 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 11.22 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 15.63 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 13.08 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 16.73 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 15.79 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 14.24 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 11.16 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 17.05 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 13.07 seconds
# Cosinor fitted to sine 01 and results saved!
# Time elapsed: 13.00 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 10.18 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 11.88 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 9.04 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 7.99 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 10.47 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 14.87 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 11.13 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 15.44 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 15.28 seconds
# Cosinor fitted to sine 05 and results saved!
# Time elapsed: 12.92 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 9.36 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 12.69 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 9.92 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 7.94 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 9.81 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 13.87 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 11.39 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 14.84 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 12.63 seconds
# Cosinor fitted to sine 10 and results saved!
# Time elapsed: 12.60 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 10.29 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 13.06 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 14.35 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 10.23 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 11.68 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 14.57 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 12.32 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 12.27 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 9.96 seconds
# Cosinor fitted to square 0 and results saved!
# Time elapsed: 12.32 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 13.39 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 14.52 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 15.16 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 9.93 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 12.22 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 15.07 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 13.41 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 14.38 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 11.70 seconds
# Cosinor fitted to square 0.1 and results saved!
# Time elapsed: 12.02 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 10.79 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 15.80 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 13.97 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 8.66 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 11.55 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 14.05 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 12.63 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 12.30 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 9.90 seconds
# Cosinor fitted to square 0.5 and results saved!
# Time elapsed: 11.47 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 10.47 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 12.69 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 13.67 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 9.03 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 11.77 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 14.10 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 12.28 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 12.48 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 10.32 seconds
# Cosinor fitted to square 01 and results saved!
# Time elapsed: 11.30 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 10.55 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 12.42 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 13.66 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 9.21 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 19.67 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 17.48 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 13.47 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 13.56 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 10.54 seconds
# Cosinor fitted to square 05 and results saved!
# Time elapsed: 12.24 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 10.97 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 13.66 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 14.13 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 9.13 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 12.18 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 14.72 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 14.39 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 13.52 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 11.16 seconds
# Cosinor fitted to square 10 and results saved!
# Time elapsed: 11.92 seconds

# %% [markdown]
# ### COMPARE THE MODEL RESULTS FOR EACH CYCLE

# %%
read = True                                                                                                                               # If you already ran the analysis, set this to True to read the data instead of running the analysis again
model_error = {}                                                                                                                          # Create an empty list to store the model error
mean_model_error = {}                                                                                                                     # Create an empty list to store the mean model error
std_model_error = {}                                                                                                                      # Create an empty list to store the standard deviation of the model error
num_model_error = {}                                                                                                                      # Create an empty list to store the number of model error

for sig in simulations:
      model_error[sig] = {}                                                                                                               # Create an empty list to store the model error for each type of signal
      mean_model_error[sig] = {}                                                                                                          # Create an empty list to store the mean model error for each type of signal
      std_model_error[sig] = {}                                                                                                           # Create an empty list to store the standard deviation of the model error for each type of signal
      num_model_error[sig] = {}                                                                                                           # Create an empty list to store the number of model error for each type of signal
      for noise in simulations[sig]:
            model_error[sig][noise] = []                                                                                                  # Create an empty list to store the model error for each amplitude of noise            
            result_folder = simulations[sig][noise]['save_folder']                                                                        # Get the folder to save the file
            for sim in simulations[sig][noise]:                                                                                           # For each simulation (simulation)
                  if sim != 'save_folder':  
                        if read == True:
                              type_folder = sim.split('_', 1)[1]                                                                          # Get the type of signal
                              print(result_folder + '/cosinor_' + sim + '_.xlsx')
                              best_models = pandas.read_excel(result_folder + '/cosinor_' + sim + '_.xlsx')                               # Read the data
                              simulations[sig][noise][sim]['best_models'] = best_models                                                    # Store the data in the dictionary
                        
                        simulations[sig][noise][sim]['activity_period_model'] = list(simulations[sig][noise][sim]['best_models']['period']) # Get the activity period calculated by the model
                        
                        for stage in range(len(simulations[sig][noise][sim]['activity_period_model'])):
                              param = simulations[sig][noise][sim]['activity_period_model'][stage]
                              ground_truth = simulations[sig][noise][sim]['activity_period'][stage]
                              print(param, ground_truth)
                              simulation_model_error = param - ground_truth
                                                      
                              model_error[sig][noise].append(simulation_model_error)                                                                # Store the model error in the list

                        mean_model_error[sig][noise] = abs(numpy.mean(model_error[sig][noise]))                         # Calculate the mean model error
                        std_model_error[sig][noise] = numpy.std(model_error[sig][noise])                                # Calculate the standard deviation of the model error
                        num_model_error[sig][noise] = len(model_error[sig][noise])                                      # Calculate the number of model error
# Out:
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_0_sawtooth_0_.xlsx
# 25.66000000000057 25.5
# 23.88000000000029 23.66
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_1_sawtooth_0_.xlsx
# 22.0 22.16
# 23.34000000000021 23.61
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_2_sawtooth_0_.xlsx
# 22.41000000000006 22.33
# 23.18000000000018 23.08
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_3_sawtooth_0_.xlsx
# 25.51000000000055 25.35
# 24.60000000000041 24.55
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_4_sawtooth_0_.xlsx
# 22.89000000000014 22.73
# 23.40000000000022 23.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_5_sawtooth_0_.xlsx
# 25.99000000000062 25.81
# 24.79000000000044 24.87
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_6_sawtooth_0_.xlsx
# 25.2300000000005 24.98
# 23.9200000000003 24.04
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_7_sawtooth_0_.xlsx
# 22.75000000000012 22.7
# 24.28000000000036 24.6
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_8_sawtooth_0_.xlsx
# 25.8700000000006 25.86
# 22.44000000000007 22.24
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0/cosinor_9_sawtooth_0_.xlsx
# 25.8500000000006 25.21
# 22.78000000000012 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_0_sawtooth_0.1_.xlsx
# 25.99000000000062 25.5
# 24.41000000000038 23.66
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_1_sawtooth_0.1_.xlsx
# 22.0 22.16
# 24.21000000000035 23.61
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_2_sawtooth_0.1_.xlsx
# 22.37000000000006 22.33
# 23.21000000000019 23.08
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_3_sawtooth_0.1_.xlsx
# 25.12000000000049 25.35
# 25.42000000000053 24.55
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_4_sawtooth_0.1_.xlsx
# 23.39000000000022 22.73
# 23.17000000000018 23.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_5_sawtooth_0.1_.xlsx
# 25.99000000000062 25.81
# 23.36000000000021 24.87
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_6_sawtooth_0.1_.xlsx
# 25.99000000000062 24.98
# 24.33000000000036 24.04
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_7_sawtooth_0.1_.xlsx
# 23.32000000000021 22.7
# 24.07000000000032 24.6
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_8_sawtooth_0.1_.xlsx
# 25.90000000000061 25.86
# 22.09000000000001 22.24
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.1/cosinor_9_sawtooth_0.1_.xlsx
# 25.99000000000062 25.21
# 22.0 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_0_sawtooth_0.5_.xlsx
# 25.58000000000056 25.5
# 23.79000000000028 23.66
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_1_sawtooth_0.5_.xlsx
# 22.0 22.16
# 23.2700000000002 23.61
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_2_sawtooth_0.5_.xlsx
# 22.37000000000006 22.33
# 23.2900000000002 23.08
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_3_sawtooth_0.5_.xlsx
# 25.70000000000058 25.35
# 24.38000000000037 24.55
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_4_sawtooth_0.5_.xlsx
# 22.71000000000011 22.73
# 23.35000000000021 23.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_5_sawtooth_0.5_.xlsx
# 25.99000000000062 25.81
# 24.61000000000041 24.87
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_6_sawtooth_0.5_.xlsx
# 25.39000000000053 24.98
# 24.5800000000004 24.04
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_7_sawtooth_0.5_.xlsx
# 22.40000000000006 22.7
# 23.76000000000028 24.6
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_8_sawtooth_0.5_.xlsx
# 25.37000000000053 25.86
# 22.0 22.24
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_0.5/cosinor_9_sawtooth_0.5_.xlsx
# 25.99000000000062 25.21
# 22.76000000000012 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_0_sawtooth_01_.xlsx
# 24.79000000000044 25.5
# 23.2600000000002 23.66
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_1_sawtooth_01_.xlsx
# 22.34000000000005 22.16
# 23.2900000000002 23.61
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_2_sawtooth_01_.xlsx
# 22.56000000000009 22.33
# 23.21000000000019 23.08
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_3_sawtooth_01_.xlsx
# 25.99000000000062 25.35
# 24.36000000000037 24.55
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_4_sawtooth_01_.xlsx
# 22.90000000000014 22.73
# 23.60000000000025 23.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_5_sawtooth_01_.xlsx
# 24.93000000000046 25.81
# 24.97000000000046 24.87
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_6_sawtooth_01_.xlsx
# 25.56000000000056 24.98
# 23.97000000000031 24.04
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_7_sawtooth_01_.xlsx
# 23.47000000000023 22.7
# 24.32000000000036 24.6
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_8_sawtooth_01_.xlsx
# 25.65000000000057 25.86
# 22.11000000000002 22.24
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_01/cosinor_9_sawtooth_01_.xlsx
# 25.99000000000062 25.21
# 22.0 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_0_sawtooth_05_.xlsx
# 25.30000000000052 25.5
# 24.06000000000032 23.66
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_1_sawtooth_05_.xlsx
# 22.0 22.16
# 23.23000000000019 23.61
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_2_sawtooth_05_.xlsx
# 22.43000000000007 22.33
# 23.35000000000021 23.08
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_3_sawtooth_05_.xlsx
# 25.8300000000006 25.35
# 24.98000000000047 24.55
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_4_sawtooth_05_.xlsx
# 22.86000000000013 22.73
# 23.39000000000022 23.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_5_sawtooth_05_.xlsx
# 25.99000000000062 25.81
# 24.32000000000036 24.87
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_6_sawtooth_05_.xlsx
# 25.39000000000053 24.98
# 23.76000000000028 24.04
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_7_sawtooth_05_.xlsx
# 23.01000000000016 22.7
# 24.17000000000034 24.6
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_8_sawtooth_05_.xlsx
# 25.70000000000058 25.86
# 22.82000000000013 22.24
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_05/cosinor_9_sawtooth_05_.xlsx
# 25.99000000000062 25.21
# 22.99000000000015 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_0_sawtooth_10_.xlsx
# 25.63000000000057 25.5
# 24.14000000000033 23.66
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_1_sawtooth_10_.xlsx
# 22.0 22.16
# 23.51000000000024 23.61
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_2_sawtooth_10_.xlsx
# 22.42000000000007 22.33
# 23.3000000000002 23.08
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_3_sawtooth_10_.xlsx
# 25.26000000000051 25.35
# 24.74000000000043 24.55
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_4_sawtooth_10_.xlsx
# 22.79000000000012 22.73
# 23.34000000000021 23.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_5_sawtooth_10_.xlsx
# 25.99000000000062 25.81
# 24.69000000000042 24.87
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_6_sawtooth_10_.xlsx
# 25.2100000000005 24.98
# 23.88000000000029 24.04
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_7_sawtooth_10_.xlsx
# 22.82000000000013 22.7
# 24.30000000000036 24.6
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_8_sawtooth_10_.xlsx
# 25.96000000000062 25.86
# 22.77000000000012 22.24
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sawtooth_10/cosinor_9_sawtooth_10_.xlsx
# 25.99000000000062 25.21
# 22.80000000000013 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_0_sine_0_.xlsx
# 25.79000000000059 25.79
# 23.40000000000022 23.4
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_1_sine_0_.xlsx
# 22.71000000000011 22.71
# 25.77000000000059 25.77
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_2_sine_0_.xlsx
# 25.02000000000047 25.02
# 24.16000000000034 24.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_3_sine_0_.xlsx
# 22.47000000000007 22.47
# 23.11000000000017 23.11
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_4_sine_0_.xlsx
# 24.87000000000045 24.87
# 23.01000000000016 23.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_5_sine_0_.xlsx
# 24.29000000000036 24.29
# 25.01000000000047 25.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_6_sine_0_.xlsx
# 25.88000000000061 25.88
# 22.81000000000013 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_7_sine_0_.xlsx
# 23.42000000000022 23.42
# 22.79000000000012 22.79
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_8_sine_0_.xlsx
# 22.52000000000008 22.52
# 22.47000000000007 22.47
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0/cosinor_9_sine_0_.xlsx
# 23.83000000000029 23.83
# 23.76000000000028 23.76
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_0_sine_0.1_.xlsx
# 25.47000000000054 25.79
# 24.70000000000042 23.4
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_1_sine_0.1_.xlsx
# 22.82000000000013 22.71
# 25.70000000000058 25.77
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_2_sine_0.1_.xlsx
# 24.90000000000045 25.02
# 24.20000000000034 24.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_3_sine_0.1_.xlsx
# 22.0 22.47
# 24.10000000000033 23.11
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_4_sine_0.1_.xlsx
# 24.88000000000045 24.87
# 22.81000000000013 23.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_5_sine_0.1_.xlsx
# 24.05000000000032 24.29
# 25.33000000000052 25.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_6_sine_0.1_.xlsx
# 25.66000000000057 25.88
# 23.8900000000003 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_7_sine_0.1_.xlsx
# 23.36000000000021 23.42
# 22.68000000000011 22.79
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_8_sine_0.1_.xlsx
# 22.68000000000011 22.52
# 22.37000000000006 22.47
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.1/cosinor_9_sine_0.1_.xlsx
# 23.77000000000028 23.83
# 23.43000000000022 23.76
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_0_sine_0.5_.xlsx
# 25.29000000000051 25.79
# 24.19000000000034 23.4
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_1_sine_0.5_.xlsx
# 22.76000000000012 22.71
# 25.76000000000059 25.77
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_2_sine_0.5_.xlsx
# 24.45000000000038 25.02
# 23.9400000000003 24.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_3_sine_0.5_.xlsx
# 22.73000000000011 22.47
# 23.06000000000017 23.11
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_4_sine_0.5_.xlsx
# 24.89000000000045 24.87
# 23.54000000000024 23.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_5_sine_0.5_.xlsx
# 24.36000000000037 24.29
# 25.15000000000049 25.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_6_sine_0.5_.xlsx
# 25.99000000000062 25.88
# 24.28000000000036 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_7_sine_0.5_.xlsx
# 23.46000000000023 23.42
# 22.78000000000012 22.79
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_8_sine_0.5_.xlsx
# 22.29000000000005 22.52
# 22.59000000000009 22.47
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_0.5/cosinor_9_sine_0.5_.xlsx
# 23.9100000000003 23.83
# 23.81000000000028 23.76
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_0_sine_01_.xlsx
# 25.99000000000062 25.79
# 22.91000000000014 23.4
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_1_sine_01_.xlsx
# 22.68000000000011 22.71
# 25.51000000000055 25.77
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_2_sine_01_.xlsx
# 25.29000000000051 25.02
# 24.30000000000036 24.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_3_sine_01_.xlsx
# 22.40000000000006 22.47
# 23.16000000000018 23.11
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_4_sine_01_.xlsx
# 24.5600000000004 24.87
# 23.24000000000019 23.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_5_sine_01_.xlsx
# 24.23000000000035 24.29
# 25.1800000000005 25.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_6_sine_01_.xlsx
# 25.99000000000062 25.88
# 23.47000000000023 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_7_sine_01_.xlsx
# 23.44000000000023 23.42
# 22.92000000000014 22.79
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_8_sine_01_.xlsx
# 22.6700000000001 22.52
# 22.40000000000006 22.47
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_01/cosinor_9_sine_01_.xlsx
# 23.79000000000028 23.83
# 23.74000000000027 23.76
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_0_sine_05_.xlsx
# 25.51000000000055 25.79
# 23.82000000000028 23.4
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_1_sine_05_.xlsx
# 22.97000000000015 22.71
# 25.80000000000059 25.77
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_2_sine_05_.xlsx
# 24.86000000000045 25.02
# 24.42000000000038 24.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_3_sine_05_.xlsx
# 22.6300000000001 22.47
# 23.2900000000002 23.11
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_4_sine_05_.xlsx
# 25.2300000000005 24.87
# 23.49000000000023 23.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_5_sine_05_.xlsx
# 24.29000000000036 24.29
# 24.86000000000045 25.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_6_sine_05_.xlsx
# 25.89000000000061 25.88
# 22.43000000000007 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_7_sine_05_.xlsx
# 23.3100000000002 23.42
# 22.80000000000013 22.79
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_8_sine_05_.xlsx
# 22.58000000000009 22.52
# 22.44000000000007 22.47
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_05/cosinor_9_sine_05_.xlsx
# 23.88000000000029 23.83
# 23.62000000000025 23.76
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_0_sine_10_.xlsx
# 25.93000000000061 25.79
# 23.53000000000024 23.4
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_1_sine_10_.xlsx
# 22.76000000000012 22.71
# 25.62000000000057 25.77
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_2_sine_10_.xlsx
# 24.90000000000045 25.02
# 24.21000000000035 24.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_3_sine_10_.xlsx
# 22.58000000000009 22.47
# 23.3000000000002 23.11
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_4_sine_10_.xlsx
# 24.76000000000043 24.87
# 22.96000000000015 23.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_5_sine_10_.xlsx
# 24.26000000000035 24.29
# 25.11000000000049 25.01
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_6_sine_10_.xlsx
# 25.8200000000006 25.88
# 22.82000000000013 22.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_7_sine_10_.xlsx
# 23.37000000000021 23.42
# 22.80000000000013 22.79
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_8_sine_10_.xlsx
# 22.57000000000009 22.52
# 22.49000000000008 22.47
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\sine_10/cosinor_9_sine_10_.xlsx
# 23.82000000000028 23.83
# 23.72000000000027 23.76
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_0_square_0_.xlsx
# 25.79000000000059 25.73
# 24.67000000000042 24.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_1_square_0_.xlsx
# 22.44000000000007 22.4
# 24.82000000000044 24.82
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_2_square_0_.xlsx
# 25.00000000000047 24.95
# 22.91000000000014 22.98
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_3_square_0_.xlsx
# 25.39000000000053 25.38
# 23.05000000000016 23.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_4_square_0_.xlsx
# 23.19000000000019 23.19
# 22.6100000000001 22.51
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_5_square_0_.xlsx
# 24.33000000000036 24.32
# 25.28000000000051 25.25
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_6_square_0_.xlsx
# 23.9300000000003 23.89
# 23.88000000000029 23.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_7_square_0_.xlsx
# 25.59000000000056 25.59
# 25.45000000000054 25.49
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_8_square_0_.xlsx
# 24.79000000000044 24.73
# 25.73000000000058 25.73
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0/cosinor_9_square_0_.xlsx
# 24.35000000000037 24.36
# 23.83000000000029 23.94
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_0_square_0.1_.xlsx
# 25.99000000000062 25.73
# 24.5500000000004 24.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_1_square_0.1_.xlsx
# 22.32000000000005 22.4
# 25.05000000000048 24.82
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_2_square_0.1_.xlsx
# 25.08000000000048 24.95
# 23.11000000000017 22.98
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_3_square_0.1_.xlsx
# 25.02000000000047 25.38
# 22.47000000000007 23.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_4_square_0.1_.xlsx
# 23.2900000000002 23.19
# 22.58000000000009 22.51
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_5_square_0.1_.xlsx
# 24.32000000000036 24.32
# 25.64000000000057 25.25
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_6_square_0.1_.xlsx
# 24.04000000000032 23.89
# 23.78000000000028 23.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_7_square_0.1_.xlsx
# 25.59000000000056 25.59
# 25.25000000000051 25.49
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_8_square_0.1_.xlsx
# 25.25000000000051 24.73
# 25.99000000000062 25.73
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.1/cosinor_9_square_0.1_.xlsx
# 24.08000000000033 24.36
# 23.70000000000027 23.94
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_0_square_0.5_.xlsx
# 25.99000000000062 25.73
# 24.25000000000035 24.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_1_square_0.5_.xlsx
# 22.57000000000009 22.4
# 24.62000000000041 24.82
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_2_square_0.5_.xlsx
# 25.39000000000053 24.95
# 22.79000000000012 22.98
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_3_square_0.5_.xlsx
# 25.55000000000055 25.38
# 23.03000000000016 23.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_4_square_0.5_.xlsx
# 23.21000000000019 23.19
# 22.59000000000009 22.51
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_5_square_0.5_.xlsx
# 24.21000000000035 24.32
# 25.57000000000056 25.25
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_6_square_0.5_.xlsx
# 24.04000000000032 23.89
# 24.42000000000038 23.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_7_square_0.5_.xlsx
# 25.8500000000006 25.59
# 25.35000000000052 25.49
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_8_square_0.5_.xlsx
# 24.64000000000041 24.73
# 25.97000000000062 25.73
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_0.5/cosinor_9_square_0.5_.xlsx
# 24.12000000000033 24.36
# 23.79000000000028 23.94
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_0_square_01_.xlsx
# 25.56000000000056 25.73
# 25.99000000000062 24.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_1_square_01_.xlsx
# 22.16000000000003 22.4
# 24.77000000000043 24.82
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_2_square_01_.xlsx
# 24.90000000000045 24.95
# 22.84000000000013 22.98
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_3_square_01_.xlsx
# 25.30000000000052 25.38
# 24.14000000000033 23.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_4_square_01_.xlsx
# 23.24000000000019 23.19
# 22.6300000000001 22.51
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_5_square_01_.xlsx
# 24.27000000000035 24.32
# 25.42000000000053 25.25
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_6_square_01_.xlsx
# 23.88000000000029 23.89
# 23.9300000000003 23.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_7_square_01_.xlsx
# 25.99000000000062 25.59
# 25.39000000000053 25.49
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_8_square_01_.xlsx
# 24.89000000000045 24.73
# 25.34000000000052 25.73
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_01/cosinor_9_square_01_.xlsx
# 24.22000000000035 24.36
# 23.62000000000025 23.94
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_0_square_05_.xlsx
# 25.76000000000059 25.73
# 24.40000000000038 24.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_1_square_05_.xlsx
# 22.30000000000005 22.4
# 24.88000000000045 24.82
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_2_square_05_.xlsx
# 25.03000000000047 24.95
# 22.88000000000014 22.98
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_3_square_05_.xlsx
# 25.35000000000052 25.38
# 22.6100000000001 23.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_4_square_05_.xlsx
# 23.16000000000018 23.19
# 22.59000000000009 22.51
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_5_square_05_.xlsx
# 24.34000000000037 24.32
# 25.41000000000053 25.25
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_6_square_05_.xlsx
# 23.8900000000003 23.89
# 23.9000000000003 23.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_7_square_05_.xlsx
# 25.58000000000056 25.59
# 25.40000000000053 25.49
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_8_square_05_.xlsx
# 24.86000000000045 24.73
# 25.65000000000057 25.73
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_05/cosinor_9_square_05_.xlsx
# 24.31000000000036 24.36
# 23.9500000000003 23.94
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_0_square_10_.xlsx
# 25.8400000000006 25.73
# 24.91000000000045 24.35
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_1_square_10_.xlsx
# 22.42000000000007 22.4
# 24.82000000000044 24.82
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_2_square_10_.xlsx
# 25.06000000000048 24.95
# 22.92000000000014 22.98
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_3_square_10_.xlsx
# 25.31000000000052 25.38
# 23.24000000000019 23.16
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_4_square_10_.xlsx
# 23.17000000000018 23.19
# 22.6100000000001 22.51
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_5_square_10_.xlsx
# 24.32000000000036 24.32
# 25.27000000000051 25.25
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_6_square_10_.xlsx
# 23.9500000000003 23.89
# 23.87000000000029 23.81
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_7_square_10_.xlsx
# 25.68000000000058 25.59
# 25.38000000000053 25.49
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_8_square_10_.xlsx
# 24.97000000000046 24.73
# 25.64000000000057 25.73
# E:/github/nnc-ufmg/circadipy/src/analysis_examples/circadipy/results_circadipy/\square_10/cosinor_9_square_10_.xlsx
# 24.42000000000038 24.36
# 23.88000000000029 23.94

# %%
import pandas

model_error_df = pandas.DataFrame(model_error)
display(model_error_df)

mean_model_error_df = pandas.DataFrame(mean_model_error)
# Pass the first row to the last row
first_row = mean_model_error_df.iloc[0]
mean_model_error = pandas.concat([mean_model_error_df.iloc[1:], first_row.to_frame().T])
mean_model_error_df = mean_model_error_df.add_suffix('_mean')
display(mean_model_error_df)

std_model_error_df = pandas.DataFrame(std_model_error)
# Pass the first row to the last row
first_row = std_model_error_df.iloc[0]
std_model_error_df = pandas.concat([std_model_error_df.iloc[1:], first_row.to_frame().T])
std_model_error_df = std_model_error_df.add_suffix('_std')
display(std_model_error_df)

num_model_error_df = pandas.DataFrame(num_model_error)
# Pass the first row to the last row
first_row = num_model_error_df.iloc[0]
num_model_error_df = pandas.concat([num_model_error_df.iloc[1:], first_row.to_frame().T])
num_model_error_df = num_model_error_df.add_suffix('_num')
display(num_model_error_df)

unique_df = pandas.concat([mean_model_error_df, std_model_error_df, num_model_error_df], axis = 1)
display(unique_df)
# Save excel file
unique_df.to_excel(main_save_folder + '/ground_truth_comparison_results.xlsx')
# Out:
#                                               sawtooth  \
# 0    [0.16000000000056858, 0.22000000000029019, -0....
# 0.1  [0.49000000000062016, 0.7500000000003801, -0.1...
# 0.5  [0.08000000000055962, 0.13000000000027967, -0....
# 01   [-0.7099999999995603, -0.3999999999997996, 0.1...
# 05   [-0.1999999999994806, 0.4000000000003183, -0.1...
# 10   [0.130000000000571, 0.48000000000033083, -0.16...
#
#                                                   sine  \
# 0    [5.897504706808832e-13, 2.2026824808563106e-13...
# 0.1  [-0.31999999999946027, 1.30000000000042, 0.110...
# 0.5  [-0.4999999999994884, 0.7900000000003402, 0.05...
# 01   [0.20000000000062101, -0.4899999999998599, -0....
# 05   [-0.27999999999945047, 0.42000000000028237, 0....
# 10   [0.14000000000061164, 0.1300000000002406, 0.05...
#
#                                                 square
# 0    [0.06000000000058847, 0.3200000000004195, 0.04...
# 0.1  [0.26000000000061974, 0.2000000000003972, -0.0...
# 0.5  [0.26000000000061974, -0.0999999999996497, 0.1...
# 01   [-0.16999999999944038, 1.6400000000006187, -0....
# 05   [0.030000000000590887, 0.0500000000003773, -0....
# 10   [0.11000000000059984, 0.5600000000004499, 0.02...
#      sawtooth_mean     sine_mean  square_mean
# 0.1         0.1445  8.550000e-02       0.0260
# 0.5         0.0075  1.070000e-01       0.0685
# 01          0.0085  3.900000e-02       0.0950
# 05          0.1065  5.150000e-02       0.0165
# 10          0.1050  1.200000e-02       0.0550
# 0           0.0665  2.900791e-13       0.0225
#      sawtooth_std      sine_std  square_std
# 0.1      0.609815  4.721703e-01    0.275216
# 0.5      0.362269  4.270726e-01    0.232062
# 01       0.475755  2.338782e-01    0.453845
# 05       0.355321  2.221773e-01    0.142628
# 10       0.256310  8.947625e-02    0.142074
# 0        0.203452  1.797943e-13    0.087171
#      sawtooth_num  sine_num  square_num
# 0.1            20        20          20
# 0.5            20        20          20
# 01             20        20          20
# 05             20        20          20
# 10             20        20          20
# 0              20        20          20
#      sawtooth_mean     sine_mean  square_mean  sawtooth_std      sine_std  \
# 0.1         0.1445  8.550000e-02       0.0260      0.609815  4.721703e-01
# 0.5         0.0075  1.070000e-01       0.0685      0.362269  4.270726e-01
# 01          0.0085  3.900000e-02       0.0950      0.475755  2.338782e-01
# 05          0.1065  5.150000e-02       0.0165      0.355321  2.221773e-01
# 10          0.1050  1.200000e-02       0.0550      0.256310  8.947625e-02
# 0           0.0665  2.900791e-13       0.0225      0.203452  1.797943e-13
#
#      square_std  sawtooth_num  sine_num  square_num
# 0.1    0.275216            20        20          20
# 0.5    0.232062            20        20          20
# 01     0.453845            20        20          20
# 05     0.142628            20        20          20
# 10     0.142074            20        20          20
# 0      0.087171            20        20          20

# %%
## PLOT THE RESULTS OF THE COMPARISON ----------------------------------------------------------------------------------

# Plot the mean and std for each signal shape and each noise level
# Set the colors for each row
colors = ['gray', 'darkgray', 'lightsteelblue', 'cornflowerblue', 'royalblue', 'midnightblue']

# Create a figure and axis
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 0.15

# Create a NumPy array with the index values
x = numpy.arange(len(mean_model_error_df.columns))

# Plot each row as a separate bar with a specific color
for i, (index, row) in enumerate(mean_model_error_df.iterrows()):
    if index == '0':
        label_name = 'Without Noise'
    else:
        if index[0] == '0' and index[1] != '.':
            label_name = f'{index[1]}dB'
        else:
            label_name = f'{index}dB'
        
    # bar with error std
    ax.errorbar(x + (i * bar_width), row, yerr=std_model_error_df.loc[index], fmt='none', ecolor='black', capsize=3)
    ax.bar(x + (i * bar_width), row, bar_width, label=label_name, color=colors[i])

# Set the labels and title
ax.set_xticks(x + (2 * bar_width))
ax.set_xticklabels([c.upper().split('_', 1)[0] for c in mean_model_error_df.columns])

# Set legend to be in row
ax.legend(frameon=False, ncol=int(i/2))
ax.set_xlabel('SIGNAL SHAPE')
ax.set_ylabel('ERROR IN HOURS (CIRCADIPY - GROUND TRUTH) ')
ax.set_ylim(-0.5, 1)

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig('comparison_circadipy.svg')

# %% [markdown]
# ### PLOT THE RESULTS
#
# It may take a while to run

# %%
format = 'svg'

for sig in simulations:
      for noise in simulations[sig]:
            for sim in simulations[sig][noise]:                                                                             # For each simulation (simulation)
                  result_folder = simulations[sig][noise]['save_folder']
                  if sim != 'save_folder': 
                        chp.actogram_bar(simulations[sig][noise][sim]['protocol'], first_hour = 18, save_folder = result_folder, save_suffix = 'bar', adjust_figure = [2, 0.95, 0.80, 0.20, 0.05], format = format)

                        chp.actogram_colormap(simulations[sig][noise][sim]['protocol'], first_hour = 18, save_folder = result_folder, save_suffix = 'colormap', adjust_figure = [2, 0.95, 0.80, 0.20, 0.05], norm_color = None, format = format)
                        chp.data_periodogram(simulations[sig][noise][sim]['protocol'], time_shape = 'continuous', method = 'periodogram', max_period = 48, unit_of_measurement = 'AMPLITUDE', save_folder = result_folder, save_suffix = 'periodogram', format = format)
                        chp.data_periodogram(simulations[sig][noise][sim]['protocol'], time_shape = 'continuous', method = 'welch', max_period = 48, unit_of_measurement = 'AMPLITUDE', save_folder = result_folder, save_suffix = 'welch', format = format)

                        chp.model_overview_detailed(simulations[sig][noise][sim]['protocol'], simulations[sig][noise][sim]['best_models_fixed'], save_folder = result_folder, format = format)
                        chp.model_overview(simulations[sig][noise][sim]['protocol'], simulations[sig][noise][sim]['best_models'], save_folder = result_folder, format = format)
                        chp.model_over_signal(simulations[sig][noise][sim]['protocol'], simulations[sig][noise][sim]['best_models'], position = 'head', mv_avg_window = 1, save_folder = result_folder, format = format)

                        chp.time_serie(simulations[sig][noise][sim]['protocol'], title = 'TIME SERIES', x_label = 'TIME (DAYS)', y_label = 'AMPLITUDE', save_folder = result_folder, format = format)

# %% [markdown]
# ### RUN THE MODELING FOR SPECIFIED DAY WINDOWS

# %%
dict = {'day_window': 1, 
        'step': 0.01, 
        'start_time': 22, 
        'end_time': 26, 
        'n_components': [1]}

best_models = []

for sig in simulations:
      for noise in simulations[sig]:
            for sim in simulations[sig][noise]:                                                                             # For each simulation (simulation)
                  result_folder = simulations[sig][noise]['save_folder']
                  if sim != 'save_folder': 
                        init = time.time()

                        best_models_per_day, best_models_per_day_file = chrt.fit_cosinor_per_day(simulations[sig][noise][sim]['protocol'], dict = dict, plot = True, save_folder = result_folder) 
                        chp.model_per_day(simulations[sig][noise][sim]['protocol'], best_models_per_day, dict['day_window'], save_folder = result_folder, save_suffix = '', format = format)   
                        simulations[sig][noise][sim]['best_models_per_day'] = best_models_per_day
                        simulations[sig][noise][sim]['best_models_file_per_day'] = best_models_per_day_file
